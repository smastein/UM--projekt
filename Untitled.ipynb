# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import matplotlib.pyplot as plt
import tensorflow as tf
import keras, sys, time, os, warnings, cv2

from keras.models import *
from keras.layers import *

import numpy as np
import pandas as pd 

import glob
import os
import pickle as pkl
import datetime

from keras.optimizers import RMSprop
from keras.callbacks import CSVLogger, ModelCheckpoint
from keras.models import load_model, model_from_json
from keras.losses import mean_squared_error

from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import UpSampling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Activation
from keras.layers import Add
from keras.models import Input
from keras.models import Model

# %%
def get_data(path):
    images = []
    masks = []
    keypoints = None
    for subdir, dirs, files in os.walk(path):
        for filename in files:
            filepath = subdir + os.sep + filename
            if filepath.endswith(".jpg") or filepath.endswith(".png") and 'color' in filepath and 'color_back' not in filepath:
                img = cv2.imread(filepath)
                images.append(img)
            if filepath.endswith(".jpg") or filepath.endswith(".png") and 'mask' in filepath :
                img = cv2.imread(filepath)
                masks.append(img)
            if 'keypoints' in filename:
                keypoints = pd.read_csv(filepath, delim_whitespace=True, header=None)
                keypoints = np.array(keypoints)
    masks = np.array(masks)
    images = np.array(images)
    return images, masks, keypoints

def gaussian_k(x0,y0,sigma, width, height):
        """ Make a square gaussian kernel centered at (x0, y0) with sigma as SD.
        """
        x = np.arange(0, width, 1, float) ## (width,)
        y = np.arange(0, height, 1, float)[:, np.newaxis] ## (height,1)
        return np.exp(-((x-x0)**2 + (y-y0)**2) / (2*sigma**2))

# %%
example_path = r"Cropped\Cropped\Cropped_384\ir_fm_f"
images_path = os.path.join(example_path,'color')
images_im, masks_im, keypoint_im = get_data(example_path)
to_shuffle = list(zip(images_im, masks_im, keypoint_im))
images_im, masks_im, keypoint_im = zip(*to_shuffle)
images_im = np.array(images_im)
masks_im = np.array(masks_im)
keypoint_im = np.array(keypoint_im)
prop_train = 0.8
Ntrain = int(images_im.shape[0]*prop_train)
i_train_im, m_train_im, i_val_im, m_val_im  = images_im[:Ntrain], masks_im[:Ntrain], images_im[Ntrain:], masks_im[Ntrain:]

# %%
counter = 0
keypoint_nr = 0
for subdir, dirs, files in os.walk(images_path):
    for filename in files:
        filepath = subdir + os.sep + filename
        if filepath.endswith(".jpg") or filepath.endswith(".png") and counter == keypoint_nr:
            img = cv2.imread(filepath)
            fig, plot = plt.subplots()
            for i in range(0,12,2):
                x = keypoint_im[keypoint_nr,i]
                y = keypoint_im[keypoint_nr,i+1]
                plot.scatter(x, y, 256, c="r", marker="+") # plot markers    
            plot.set_xticks(())
            plot.set_yticks(())
            plt.imshow(img, cmap="gray") # plot image
            plt.tight_layout()
            plt.show()
            keypoint_nr = keypoint_nr + 1
            break
        counter = counter + 1

# %%
train_path = r"\Cropped\Cropped\Cropped_384"
images = []
keypoints = []
for subdir, dirs, files in os.walk(train_path):
    for filename in files:
        filepath = subdir + os.sep + filename
        if filepath.endswith(".jpg") or filepath.endswith(".png") and 'color' in filepath :
            img = cv2.imread(filepath)
            images.append(img[384:732, 768:1152])
        if filepath.endswith(".jpg") or filepath.endswith(".png") and 'mask' in filepath:
            mask = cv2.imread(filepath)
            masks.append(mask[384:732, 768:1152])
        if filepath.endswith(".txt"):
            arr = np.loadtxt(filepath)
            for keypoint in arr:
                keypoints.append(keypoint)

# %%
keypoints_im_gaussian = []
for k in keypoint_im:
    image_kp = []
    for x in range(0,18,2):
        size = 20
        kp=np.zeros((384,384))
        g = gaussian_k(size/2,size/2,4,size,size)
        kp[int(k[x]-size/2):int(k[x]+size/2),int(k[x+1]-size/2):int(k[x+1]+size/2)] = g
        image_kp.append(kp*255)
    keypoints_im_gaussian.append(np.array(image_kp).T)
keypoints_im_gaussian = np.array(keypoints_im_gaussian)

# %%
plt.imshow(keypoints_im_gaussian[1,:,:,1]) #example keypoint

# %%
def bottleneck(input, channels, name):
    shortcut = input
    #Make input channels same as output channel if the input has different number of channels, so we can add input with the output of last part of residual block
    if shortcut.shape[-1] != channels:
        shortcut = BatchNormalization()(shortcut)
        shortcut = Conv2D(channels,(1,1), padding="same", activation='relu', name=name + "skip_connection")(shortcut)

    #bottleneck block

    #First conv 1x1
    next = BatchNormalization()(input)
    next = Conv2D(channels//2,(1,1), padding="same", activation='relu', name=name + "conv_1x1_1")(next)

    #Second conv 3x3
    next = BatchNormalization()(next)
    next = Conv2D(channels//2,(3,3), padding="same", activation='relu', name=name + "conv_3x3")(next)

    #Third conv 1x1
    next = BatchNormalization()(next)
    next = Conv2D(channels,(1,1), padding="same", activation='relu', name=name + "conv_1x1_2")(next)

    next = Add(name=name + "residual_output")([shortcut, next])

    return next

def create_input_module(input, num_channels):
    #conv2D with strite 2, filter size 7x7 and padding of same results 1/2 resolution
    #maxpooling results into another 1/2 of resolution

    next = BatchNormalization()(input)                                                             #Image resolution: 256x256xnum_channels
    next = Conv2D(64,(7,7), padding="same", activation='relu', strides=(2,2), name="input_conv_7x7_stride_2")(next) #Image resolution: 128x128xnum_channels TODO: why not num_channels?

    next = bottleneck(next, num_channels//2,"input_module_bottlenec_1")                          #Image resolution: 128x128xnum_channels TODO: Why num_bottleNeck_channels//2
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(next)                                       #Image resolution: 64x64xnum_channels

    next = bottleneck(next, num_channels//2, "input_module_bottlenec_2")                         #Image resolution: 64x64xnum_channels TODO: Why num_bottleNeck_channels//2
    next = bottleneck(next, num_channels, "input_module_bottlenec_3")                            #Image resolution: 64x64xnum_channels

    return next

def create_hourGlass_module(input, num_classes, num_bottleNeck_channels, hourGlassId):
    hourGName = "hg" + str(hourGlassId)
    input_shortCut = input

    #First bottleneck Block
    left_b1 = bottleneck(input, num_bottleNeck_channels, hourGName + "__bottleNeck1")                #Image resolution: 64X64xnum_bottleNeck_channels
    b1_shortcut = bottleneck(left_b1, num_bottleNeck_channels, hourGName + "_bottleNeck1_shortcut")  #Image resolution: 64x64xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b1)                                       #Image resolution: 32x32xnum_bottleNeck_channels

    #Second bottleneck Block
    left_b2 = bottleneck(next, num_bottleNeck_channels, hourGName + "__bottleNeck2")                #Image resolution: 32x32xnum_bottleNeck_channels
    b2_shortcut = bottleneck(left_b2, num_bottleNeck_channels, hourGName + "_bottleNeck2_shortcut")  #Image resolution: 32x32xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b2)                                       #Image resolution: 16x16xnum_bottleNeck_channels

    #Third bottleneck Block
    left_b3 = bottleneck(next, num_bottleNeck_channels, hourGName + "__bottleNeck3")                #Image resolution: 16x16xnum_bottleNeck_channels
    b3_shortcut = bottleneck(left_b3, num_bottleNeck_channels, hourGName + "_bottleNeck3_shortcut")  #Image resolution: 16x16xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b3)                                       #Image resolution: 8x8xnum_bottleNeck_channels

    #forth bottleneck Block
    left_b4 = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck4")                 #Image resolution: 8x8xnum_bottleNeck_channels
    b4_shortcut = bottleneck(left_b4, num_bottleNeck_channels, hourGName + "_bottleNeck4_shortcut")  #Image resolution: 8x8xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b4)                                       #Image resolution: 4x4xnum_bottleNeck_channels TODO: Why not adding this max pooling?

    #creat bottom layer (3 consecutive bottlenecks)
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_1")            #Image resolution: 4x4xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_2")            #Image resolution: 4x4xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_3")            #Image resolution: 4x4xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 8x8xnum_bottleNeck_channels
    next = Add()([next, b4_shortcut])                                                               #Image resolution: 8x8xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_4")             #Image resolution: 8x8xnum_bottleNeck_channels
   
    next = UpSampling2D()(next)                                                                     #Image resolution: 16x16xnum_bottleNeck_channels
    next = Add()([next, b3_shortcut])                                                               #Image resolution: 16x16xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_3")             #Image resolution: 16x16xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 32x32xnum_bottleNeck_channels
    next = Add()([next, b2_shortcut])                                                               #Image resolution: 32x32xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_2")             #Image resolution: 32x32xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 64x64xnum_bottleNeck_channels
    next = Add()([next, b1_shortcut])                                                               #Image resolution: 64x64xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_1")             #Image resolution: 64x64xnum_bottleNeck_channels

    #Intermediate supervision
    next = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='relu',
                    name=str(hourGName) + '_Intermediate_conv_1x1_1')(next)                         #Image resolution: 64x64xnum_bottleNeck_channels
    
    next = BatchNormalization()(next)                                                                 #Image resolution: 64x64xnum_bottleNeck_channels
    heatMap = Conv2D(num_classes, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_heatMap_conv_1x1_1')(next)                 #Image resolution: 64x64xnum_classes

    # next = BatchNormalization(next)                                                               #Image resolution: 64x64xnum_bottleNeck_channels
    next = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_conv_1x1_2')(next)                         #Image resolution: 64x64xnum_bottleNeck_channels

    reMapedHeatMap = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_heatMap_conv_1x1_2')(heatMap)       #Image resolution: 64x64xnum_bottleNeck_channels
    outputHead = Add()([next,input_shortCut, reMapedHeatMap])

    return outputHead, heatMap
    
    
def stack_hourGlass_modules(num_classes, num_stacks, num_channels, input_shape):
    input = Input(shape=(input_shape[0], input_shape[1], 3))

    hourGlass_next = create_input_module(input, num_channels)                                      #Create hourGlass first input module to reduce the resolution to 64x64xnum_channels
    outputs = []

    for i in range(num_stacks):
        hourGlass_next, heatmap_loss = create_hourGlass_module(hourGlass_next, num_classes, num_channels, i)
        outputs.append(heatmap_loss)
    model = Model(inputs=input, outputs=outputs)

    return model

# %%
batch_size = 8
epochs = 50

model = stack_hourGlass_modules(16, 2, 384, (384,384))
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 384, 384, 3) 0
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 384, 384, 3)  12          input_2[0][0]
# __________________________________________________________________________________________________
# input_conv_7x7_stride_2 (Conv2D (None, 192, 192, 64) 9472        batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 192, 192, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 192, 192, 96) 6240        batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 192, 192, 96) 384         input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_3x (None, 192, 192, 96) 83040       batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 192, 192, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 192, 192, 96) 384         input_module_bottlenec_1conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_1skip_co (None, 192, 192, 192 12480       batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 192, 192, 192 18624       batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1residua (None, 192, 192, 192 0           input_module_bottlenec_1skip_conn
#                                                                  input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 96, 96, 192)  0           input_module_bottlenec_1residual_
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 96, 96, 192)  768         max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 96, 96, 96)   18528       batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 96, 96, 96)   384         input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_3x (None, 96, 96, 96)   83040       batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 96, 96, 96)   384         input_module_bottlenec_2conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 96, 96, 192)  18624       batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2residua (None, 96, 96, 192)  0           max_pooling2d_9[0][0]
#                                                                  input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 96, 96, 192)  768         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 96, 96, 192)  37056       batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 96, 96, 192)  768         input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_3x (None, 96, 96, 192)  331968      batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 96, 96, 192)  768         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 96, 96, 192)  768         input_module_bottlenec_3conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_3skip_co (None, 96, 96, 384)  74112       batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 96, 96, 384)  74112       batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3residua (None, 96, 96, 384)  0           input_module_bottlenec_3skip_conn
#                                                                  input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 96, 96, 384)  1536        input_module_bottlenec_3residual_
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_1 (Con (None, 96, 96, 192)  73920       batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 96, 96, 192)  768         hg0__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_3x3 (Conv2 (None, 96, 96, 192)  331968      batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 96, 96, 192)  768         hg0__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_2 (Con (None, 96, 96, 384)  74112       batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1residual_output (None, 96, 96, 384)  0           input_module_bottlenec_3residual_
#                                                                  hg0__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 48, 48, 384)  0           hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 48, 48, 384)  1536        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_1 (Con (None, 48, 48, 192)  73920       batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 48, 48, 192)  768         hg0__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_3x3 (Conv2 (None, 48, 48, 192)  331968      batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 48, 48, 192)  768         hg0__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_2 (Con (None, 48, 48, 384)  74112       batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2residual_output (None, 48, 48, 384)  0           max_pooling2d_10[0][0]
#                                                                  hg0__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 24, 24, 384)  0           hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 24, 24, 384)  1536        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_1 (Con (None, 24, 24, 192)  73920       batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 24, 24, 192)  768         hg0__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_3x3 (Conv2 (None, 24, 24, 192)  331968      batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 24, 24, 192)  768         hg0__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_2 (Con (None, 24, 24, 384)  74112       batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3residual_output (None, 24, 24, 384)  0           max_pooling2d_11[0][0]
#                                                                  hg0__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 12, 12, 384)  0           hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 12, 12, 384)  1536        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_1 (Conv (None, 12, 12, 192)  73920       batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 12, 12, 192)  768         hg0_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_3x3 (Conv2D (None, 12, 12, 192)  331968      batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 12, 12, 192)  768         hg0_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_2 (Conv (None, 12, 12, 384)  74112       batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4residual_output  (None, 12, 12, 384)  0           max_pooling2d_12[0][0]
#                                                                  hg0_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 6, 6, 384)    0           hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 6, 6, 384)    1536        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 6, 6, 192)    73920       batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 6, 6, 192)    768         hg0_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_3x3 (None, 6, 6, 192)    331968      batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 6, 6, 192)    768         hg0_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 6, 6, 384)    74112       batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1residual (None, 6, 6, 384)    0           max_pooling2d_13[0][0]
#                                                                  hg0_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 6, 6, 384)    1536        hg0_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 6, 6, 192)    73920       batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 6, 6, 192)    768         hg0_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_3x3 (None, 6, 6, 192)    331968      batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 6, 6, 192)    768         hg0_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 6, 6, 384)    74112       batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2residual (None, 6, 6, 384)    0           hg0_bottleNeck_bottom_1residual_o
#                                                                  hg0_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 6, 6, 384)    1536        hg0_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 6, 6, 192)    73920       batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 12, 12, 384)  1536        hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 6, 6, 192)    768         hg0_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 12, 12, 192)  73920       batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_3x3 (None, 6, 6, 192)    331968      batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 12, 12, 192)  768         hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 6, 6, 192)    768         hg0_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_3x (None, 12, 12, 192)  331968      batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 6, 6, 384)    74112       batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 12, 12, 192)  768         hg0_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3residual (None, 6, 6, 384)    0           hg0_bottleNeck_bottom_2residual_o
#                                                                  hg0_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 12, 12, 384)  74112       batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 12, 12, 384)  0           hg0_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutresidua (None, 12, 12, 384)  0           hg0_bottleNeck4residual_output[0]
#                                                                  hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 384)  0           up_sampling2d_8[0][0]
#                                                                  hg0_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 12, 12, 384)  1536        add_10[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 12, 12, 192)  73920       batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 24, 24, 384)  1536        hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 12, 12, 192)  768         hg0_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 24, 24, 192)  73920       batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_3x3  (None, 12, 12, 192)  331968      batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 24, 24, 192)  768         hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 12, 12, 192)  768         hg0_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_3x (None, 24, 24, 192)  331968      batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 12, 12, 384)  74112       batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 24, 24, 192)  768         hg0_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4residual_ (None, 12, 12, 384)  0           add_10[0][0]
#                                                                  hg0_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 24, 24, 384)  74112       batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 24, 24, 384)  0           hg0_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutresidua (None, 24, 24, 384)  0           hg0__bottleNeck3residual_output[0
#                                                                  hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 24, 24, 384)  0           up_sampling2d_9[0][0]
#                                                                  hg0_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 24, 24, 384)  1536        add_11[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 24, 24, 192)  73920       batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 48, 48, 384)  1536        hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 24, 24, 192)  768         hg0_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 48, 48, 192)  73920       batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_3x3  (None, 24, 24, 192)  331968      batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 48, 48, 192)  768         hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 24, 24, 192)  768         hg0_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_3x (None, 48, 48, 192)  331968      batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 24, 24, 384)  74112       batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 48, 48, 192)  768         hg0_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3residual_ (None, 24, 24, 384)  0           add_11[0][0]
#                                                                  hg0_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 48, 48, 384)  74112       batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 48, 48, 384)  0           hg0_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutresidua (None, 48, 48, 384)  0           hg0__bottleNeck2residual_output[0
#                                                                  hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 48, 48, 384)  0           up_sampling2d_10[0][0]
#                                                                  hg0_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 48, 48, 384)  1536        add_12[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 48, 48, 192)  73920       batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 96, 96, 384)  1536        hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 48, 48, 192)  768         hg0_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 96, 96, 192)  73920       batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_3x3  (None, 48, 48, 192)  331968      batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 96, 96, 192)  768         hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 48, 48, 192)  768         hg0_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_3x (None, 96, 96, 192)  331968      batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 48, 48, 384)  74112       batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 96, 96, 192)  768         hg0_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2residual_ (None, 48, 48, 384)  0           add_12[0][0]
#                                                                  hg0_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 96, 96, 384)  74112       batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 96, 96, 384)  0           hg0_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutresidua (None, 96, 96, 384)  0           hg0__bottleNeck1residual_output[0
#                                                                  hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 96, 96, 384)  0           up_sampling2d_11[0][0]
#                                                                  hg0_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 96, 96, 384)  1536        add_13[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 96, 96, 192)  73920       batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 96, 96, 192)  768         hg0_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_3x3  (None, 96, 96, 192)  331968      batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 96, 96, 192)  768         hg0_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 96, 96, 384)  74112       batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1residual_ (None, 96, 96, 384)  0           add_13[0][0]
#                                                                  hg0_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_1 (Co (None, 96, 96, 384)  147840      hg0_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 96, 96, 384)  1536        hg0_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 96, 96, 16)   6160        batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_2 (Co (None, 96, 96, 384)  147840      batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 96, 96, 384)  6528        hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 96, 96, 384)  0           hg0_Intermediate_conv_1x1_2[0][0]
#                                                                  input_module_bottlenec_3residual_
#                                                                  hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 96, 96, 384)  1536        add_14[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_1 (Con (None, 96, 96, 192)  73920       batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 96, 96, 192)  768         hg1__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_3x3 (Conv2 (None, 96, 96, 192)  331968      batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 96, 96, 192)  768         hg1__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_2 (Con (None, 96, 96, 384)  74112       batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1residual_output (None, 96, 96, 384)  0           add_14[0][0]
#                                                                  hg1__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 48, 48, 384)  0           hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 48, 48, 384)  1536        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_1 (Con (None, 48, 48, 192)  73920       batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 48, 48, 192)  768         hg1__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_3x3 (Conv2 (None, 48, 48, 192)  331968      batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 48, 48, 192)  768         hg1__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_2 (Con (None, 48, 48, 384)  74112       batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2residual_output (None, 48, 48, 384)  0           max_pooling2d_14[0][0]
#                                                                  hg1__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 24, 24, 384)  0           hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 24, 24, 384)  1536        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_1 (Con (None, 24, 24, 192)  73920       batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 24, 24, 192)  768         hg1__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_3x3 (Conv2 (None, 24, 24, 192)  331968      batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 24, 24, 192)  768         hg1__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_2 (Con (None, 24, 24, 384)  74112       batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3residual_output (None, 24, 24, 384)  0           max_pooling2d_15[0][0]
#                                                                  hg1__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 12, 12, 384)  0           hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 12, 12, 384)  1536        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_1 (Conv (None, 12, 12, 192)  73920       batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 12, 12, 192)  768         hg1_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_3x3 (Conv2D (None, 12, 12, 192)  331968      batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 12, 12, 192)  768         hg1_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_2 (Conv (None, 12, 12, 384)  74112       batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4residual_output  (None, 12, 12, 384)  0           max_pooling2d_16[0][0]
#                                                                  hg1_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 6, 6, 384)    0           hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 6, 6, 384)    1536        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 6, 6, 192)    73920       batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 6, 6, 192)    768         hg1_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_3x3 (None, 6, 6, 192)    331968      batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 6, 6, 192)    768         hg1_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 6, 6, 384)    74112       batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1residual (None, 6, 6, 384)    0           max_pooling2d_17[0][0]
#                                                                  hg1_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 6, 6, 384)    1536        hg1_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 6, 6, 192)    73920       batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 6, 6, 192)    768         hg1_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_3x3 (None, 6, 6, 192)    331968      batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 6, 6, 192)    768         hg1_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 6, 6, 384)    74112       batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2residual (None, 6, 6, 384)    0           hg1_bottleNeck_bottom_1residual_o
#                                                                  hg1_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 6, 6, 384)    1536        hg1_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 6, 6, 192)    73920       batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 12, 12, 384)  1536        hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 6, 6, 192)    768         hg1_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 12, 12, 192)  73920       batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_3x3 (None, 6, 6, 192)    331968      batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 12, 12, 192)  768         hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 6, 6, 192)    768         hg1_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_3x (None, 12, 12, 192)  331968      batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 6, 6, 384)    74112       batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 12, 12, 192)  768         hg1_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3residual (None, 6, 6, 384)    0           hg1_bottleNeck_bottom_2residual_o
#                                                                  hg1_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 12, 12, 384)  74112       batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 12, 12, 384)  0           hg1_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutresidua (None, 12, 12, 384)  0           hg1_bottleNeck4residual_output[0]
#                                                                  hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 12, 12, 384)  0           up_sampling2d_12[0][0]
#                                                                  hg1_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 12, 12, 384)  1536        add_15[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 12, 12, 192)  73920       batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 24, 24, 384)  1536        hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 12, 12, 192)  768         hg1_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 24, 24, 192)  73920       batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_3x3  (None, 12, 12, 192)  331968      batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 24, 24, 192)  768         hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 12, 12, 192)  768         hg1_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_3x (None, 24, 24, 192)  331968      batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 12, 12, 384)  74112       batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 24, 24, 192)  768         hg1_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4residual_ (None, 12, 12, 384)  0           add_15[0][0]
#                                                                  hg1_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 24, 24, 384)  74112       batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 24, 24, 384)  0           hg1_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutresidua (None, 24, 24, 384)  0           hg1__bottleNeck3residual_output[0
#                                                                  hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 24, 24, 384)  0           up_sampling2d_13[0][0]
#                                                                  hg1_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 24, 24, 384)  1536        add_16[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 24, 24, 192)  73920       batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 48, 48, 384)  1536        hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 24, 24, 192)  768         hg1_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 48, 48, 192)  73920       batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_3x3  (None, 24, 24, 192)  331968      batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 48, 48, 192)  768         hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 24, 24, 192)  768         hg1_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_3x (None, 48, 48, 192)  331968      batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 24, 24, 384)  74112       batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 48, 48, 192)  768         hg1_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3residual_ (None, 24, 24, 384)  0           add_16[0][0]
#                                                                  hg1_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 48, 48, 384)  74112       batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 48, 48, 384)  0           hg1_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutresidua (None, 48, 48, 384)  0           hg1__bottleNeck2residual_output[0
#                                                                  hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 48, 48, 384)  0           up_sampling2d_14[0][0]
#                                                                  hg1_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 48, 48, 384)  1536        add_17[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 48, 48, 192)  73920       batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 96, 96, 384)  1536        hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 48, 48, 192)  768         hg1_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 96, 96, 192)  73920       batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_3x3  (None, 48, 48, 192)  331968      batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 96, 96, 192)  768         hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 48, 48, 192)  768         hg1_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_3x (None, 96, 96, 192)  331968      batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 48, 48, 384)  74112       batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 96, 96, 192)  768         hg1_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2residual_ (None, 48, 48, 384)  0           add_17[0][0]
#                                                                  hg1_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 96, 96, 384)  74112       batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 96, 96, 384)  0           hg1_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutresidua (None, 96, 96, 384)  0           hg1__bottleNeck1residual_output[0
#                                                                  hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 96, 96, 384)  0           up_sampling2d_15[0][0]
#                                                                  hg1_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 96, 96, 384)  1536        add_18[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 96, 96, 192)  73920       batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 96, 96, 192)  768         hg1_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_3x3  (None, 96, 96, 192)  331968      batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 96, 96, 192)  768         hg1_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 96, 96, 384)  74112       batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1residual_ (None, 96, 96, 384)  0           add_18[0][0]
#                                                                  hg1_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_Intermediate_conv_1x1_1 (Co (None, 96, 96, 384)  147840      hg1_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 96, 96, 384)  1536        hg1_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_Intermediate_heatMap_conv_1 (None, 96, 96, 16)   6160        batch_normalization_207[0][0]
# ==================================================================================================
# Total params: 15,730,796
# Trainable params: 15,680,230
# Non-trainable params: 50,566
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=RMSprop(lr=5e-4), loss=mean_squared_error, metrics=["accuracy"])
print("[INFO]Training...")
model.fit(generator=train_generator, steps_per_epoch=train.get_dataset_size() // batch_size,
                                 epochs=epochs, callbacks=callBacks)

# %%
"""
# construct the argument parse and parse the arguments
ap = argparse.ArgumentParser()

ap.add_argument("-nc", "--numClasses", type=int, default=16,
	help="number of classes")
ap.add_argument("-ns", "--numStacks", type=int, default=2,
	help="number of hourGlass stacks")
ap.add_argument("-nch", "--numChannels", type=int, default=256,
	help="number of residual bottleNeck channels")
ap.add_argument("-bs", "--batchSize", default=8, type=int,
    help='batch size for training')
ap.add_argument("-ep", "--epochs", default=20, type=int,
    help="number of traning epochs")
ap.add_argument("-rs", "--resume", default=False, type=bool,
    help="resume training or not")
ap.add_argument("-rsm", "--resumeModel",
    help="start point to retrain")
ap.add_argument("-rsmj", "--resumeModelJson",
    help="model json")
ap.add_argument("-c", "--checkPoints", required=True,
	help="path to output checkPoint directory")
ap.add_argument("-s", "--startEpoch", type=int, default=0,
	help="epoch to restart training at")

args = vars(ap.parse_args())
"""
#dataset_path = "data/mpii/"
batch_size = 8
epochs = 50

#Start training
print("[INFO]Loading training dataset...")
#train = MPIIDataGen(dataset_path + "mpii_annotations.json", dataset_path + "images", inres=(256,256), outres=(64,64), is_train=True)
#train_generator = train.generator(batch_size, args["numStacks"], sigma=1, is_shuffle=True, rot_flag=True, scale_flag=True, flip_flag=True)

#csvlogger = CSVLogger(os.path.join(args["checkPoints"], "csv_train_" + str(datetime.datetime.now().strftime('%H:%M')) + ".csv"))
#checkPoint = EvalCallBack(args["checkPoints"], (256,256), (64,64))

#callBacks = [csvlogger, checkPoint]

model = stack_hourGlass_modules(16, 2, 384, (384,384))
    
#show model summary
model.summary()
model.compile(optimizer=RMSprop(lr=5e-4), loss=mean_squared_error, metrics=["accuracy"])
print("[INFO]Training...")
model.fit_generator(generator=train_generator, steps_per_epoch=train.get_dataset_size() // batch_size,
                                 epochs=epochs, callbacks=callBacks)
print("[INFO]Finished training...")




#Resume Training
print("[INFO]Loading the model...")
with open(args["resumeModelJson"]) as f:
    model = model_from_json(f.read())
model.load_weights(args["resumeModel"])

model.compile(optimizer=RMSprop(lr=5e-4), loss=mean_squared_error, metrics=["accuracy"])
print("[INFO]Loading training dataset...")
train = MPIIDataGen(dataset_path + "mpii_annotations.json", dataset_path + "images", inres=(256,256), outres=(64,64), is_train=True)
train_generator = train.generator(batch_size, args["numStacks"], sigma=1, is_shuffle=True, rot_flag=True, scale_flag=True, flip_flag=True)

csvlogger = CSVLogger(os.path.join(args["checkPoints"], "csv_train_" + str(datetime.datetime.now().strftime('%H:%M')) + ".csv"))

checkpoint = EvalCallBack(args["checkPoints"], (256,256), (64,64))

callBacks = [csvlogger, checkpoint]
print("[INFO]Training...")
model.fit_generator(generator=train_generator, steps_per_epoch=train.get_dataset_size() // batch_size,
                                 initial_epoch=args["startEpoch"], epochs=epochs, callbacks=callBacks)
print("[INFO]Finished training...")

# %%
prop_train = 0.9
Ntrain = int(X_train.shape[0]*prop_train)
X_tra, y_tra, X_val,y_val = X_train[:Ntrain],y_train[:Ntrain],X_train[Ntrain:],y_train[Ntrain:]
del X_train, y_train

# %%
input_height, input_width = 96, 96
## output shape is the same as input
output_height, output_width = input_height, input_width 

# nClasses = 15
nClasses = 9 # ironman

# %%
model = []

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
# load weights into new model

loaded_model.load_weights("my_model_weights.hdf5")
model = loaded_model
model.compile(loss='mse',optimizer="rmsprop",sample_weight_mode="temporal")

print(model.output.shape)
# Out:
# (None, 82944, 1)

# %%
y_pred = model.predict(X_val)
y_pred = y_pred.reshape(-1,output_height,output_width,nClasses)

Nlandmark = y_pred.shape[-1]

# %%
for i in range(10):
	fig = plt.figure(figsize=(3,3))
	ax = fig.add_subplot(1,1,1)
	ax.imshow(X_val[i,:,:,0],cmap="gray")
	ax.axis("off")
	
	fig = plt.figure(figsize=(20,3))
	count = 1
	for j in range(9):
		ax = fig.add_subplot(2,Nlandmark,count)
# 		ax.set_title(lab[:10] + "\n" + lab[10:-2])
		ax.axis("off")
		count += 1
		ax.imshow(y_pred[i,:,:,j])
		if j == 0:
			ax.set_ylabel("prediction")
			
	for j in range(9):
		ax = fig.add_subplot(2,Nlandmark,count)
		count += 1
		ax.imshow(y_val[i,:,:,j])   
		ax.axis("off")
		if j == 0:
			ax.set_ylabel("true")

	img_name = './out/img_{:03d}.png'.format(i)
	plt.savefig( img_name, bbox_inches='tight', dpi=(300) )
	#plt.show()
	plt.close()
