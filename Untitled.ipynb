# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import matplotlib.pyplot as plt
import tensorflow as tf
import keras, sys, time, os, warnings, cv2

from keras.models import *
from keras.layers import *

import numpy as np
import pandas as pd 

import glob
import os
import pickle as pkl
import datetime

from keras.optimizers import RMSprop
from keras.callbacks import CSVLogger, ModelCheckpoint
from keras.models import load_model, model_from_json
from keras.losses import mean_squared_error

from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import UpSampling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Activation
from keras.layers import Add
from keras.models import Input
from keras.models import Model

from skimage.transform import resize

# %%
def get_data(path, color_back= False):
    images = []
    masks = []
    keypoints = None
    for subdir, dirs, files in os.walk(path):
        for filename in files:
            filepath = subdir + os.sep + filename
            if filepath.endswith(".jpg") or filepath.endswith(".png") and 'color' in filepath:
                if color_back and 'color_back' in filepath:
                    img = cv2.imread(filepath)
                    images.append(img)
                if not color_back and 'color_back' not in filepath:
                    img = cv2.imread(filepath)
                    images.append(img)
            if filepath.endswith(".jpg") or filepath.endswith(".png") and 'mask' in filepath :
                img = cv2.imread(filepath)
                masks.append(img)
            if 'keypoints' in filename:
                keypoints = pd.read_csv(filepath, delim_whitespace=True, header=None)
                keypoints = np.array(keypoints)
    masks = np.array(masks)
    images = np.array(images)
    return images, masks, keypoints

def gaussian_k(x0,y0,sigma, width, height):
        """ Make a square gaussian kernel centered at (x0, y0) with sigma as SD.
        """
        x = np.arange(0, width, 1, float) ## (width,)
        y = np.arange(0, height, 1, float)[:, np.newaxis] ## (height,1)
        return np.exp(-((x-x0)**2 + (y-y0)**2) / (2*sigma**2))
    
def data_shuffle(images, masks, keypoints):
    to_shuffle = list(zip(images, masks, keypoints))
    images_1, masks_1, keypoint_1 = zip(*to_shuffle)
    images_1 = np.array(images_1)
    masks_1 = np.array(masks_1)
    keypoint_1 = np.array(keypoint_1)
    return images_1, masks_1, keypoint_1
    
    
def images_cropped(images, masks):
    
    images_cropped=np.empty_like(images)
    images_cropped_resized=np.empty((images.shape[0],256,256,3))

    for i in range(len(images)):
        for x in range(384):
            for y in range(384):
                images_cropped[i,x,y] = images[i,x,y] * masks[i,x,y,]  
        im = resize(images_cropped[i],(int(256),int(256)),1)
        images_cropped_resized[i] = im   
    return images_cropped, images_cropped_resized

def display_picture_keypoints(images_path, keypoints, keypoint_nr):
    counter = 0
    for subdir, dirs, files in os.walk(images_path):
        for filename in files:
            filepath = subdir + os.sep + filename
            if filepath.endswith(".jpg") or filepath.endswith(".png") and counter == keypoint_nr:
                img = cv2.imread(filepath)
                fig, plot = plt.subplots()
                for i in range(0,12,2):
                    x = keypoints[keypoint_nr,i]
                    y = keypoints[keypoint_nr,i+1]
                    plot.scatter(x, y, 256, c="r", marker="+") # plot markers    
                plot.set_xticks(())
                plot.set_yticks(())
                plt.imshow(img, cmap="gray") # plot image
                plt.tight_layout()
                plt.show()
                keypoint_nr = keypoint_nr + 1
                break
            counter = counter + 1     
            
def keypoints_to_gaussian(keypoints,size =20): #keypoints for img size 256x256
    keypoints_gaussian = []
    for k in (keypoints/4): #calculate keypoints for img shape 64x64
        image_kp = []
        for x in range(0,18,2):
            kp=np.zeros((int(64),int(64)))
            g = gaussian_k(size/2,size/2,4,size,size)
            kp[int(k[x]-size/2):int(k[x]+size/2),int(k[x+1]-size/2):int(k[x+1]+size/2)] = g
            image_kp.append(kp*255)

        keypoints_gaussian.append(np.array(image_kp).T)
    return np.array(keypoints_gaussian)

def display_predictions(X_val, y_pred, y_val):
    for i in range(10):
        fig = plt.figure(figsize=(3,3))
        ax = fig.add_subplot(1,1,1)
        ax.imshow(X_val[i,:,:,0],cmap="gray")
        ax.axis("off")

        fig = plt.figure(figsize=(20,3))
        count = 1
        for j in range(9):
            ax = fig.add_subplot(2,Nlandmark,count)
            ax.axis("off")
            count += 1
            ax.imshow(y_pred[i,:,:,j])
            if j == 0:
                ax.set_ylabel("prediction")

        for j in range(9):
            ax = fig.add_subplot(2,Nlandmark,count)
            count += 1
            ax.imshow(y_val[i,:,:,j])   
            ax.axis("off")
            if j == 0:
                ax.set_ylabel("true")

# %%
def bottleneck(input, channels, name):
    shortcut = input
    #Make input channels same as output channel if the input has different number of channels, so we can add input with the output of last part of residual block
    if shortcut.shape[-1] != channels:
        shortcut = BatchNormalization()(shortcut)
        shortcut = Conv2D(channels,(1,1), padding="same", activation='relu', name=name + "skip_connection")(shortcut)

    #bottleneck block

    #First conv 1x1
    next = BatchNormalization()(input)
    next = Conv2D(channels//2,(1,1), padding="same", activation='relu', name=name + "conv_1x1_1")(next)

    #Second conv 3x3
    next = BatchNormalization()(next)
    next = Conv2D(channels//2,(3,3), padding="same", activation='relu', name=name + "conv_3x3")(next)

    #Third conv 1x1
    next = BatchNormalization()(next)
    next = Conv2D(channels,(1,1), padding="same", activation='relu', name=name + "conv_1x1_2")(next)

    next = Add(name=name + "residual_output")([shortcut, next])

    return next

def create_input_module(input, num_channels):
    #conv2D with strite 2, filter size 7x7 and padding of same results 1/2 resolution
    #maxpooling results into another 1/2 of resolution

    next = BatchNormalization()(input)                                                             #Image resolution: 256x256xnum_channels
    next = Conv2D(64,(7,7), padding="same", activation='relu', strides=(2,2), name="input_conv_7x7_stride_2")(next) #Image resolution: 128x128xnum_channels TODO: why not num_channels?

    next = bottleneck(next, num_channels//2,"input_module_bottlenec_1")                          #Image resolution: 128x128xnum_channels TODO: Why num_bottleNeck_channels//2
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(next)                                       #Image resolution: 64x64xnum_channels

    next = bottleneck(next, num_channels//2, "input_module_bottlenec_2")                         #Image resolution: 64x64xnum_channels TODO: Why num_bottleNeck_channels//2
    next = bottleneck(next, num_channels, "input_module_bottlenec_3")                            #Image resolution: 64x64xnum_channels

    return next

def create_hourGlass_module(input, num_classes, num_bottleNeck_channels, hourGlassId):
    hourGName = "hg" + str(hourGlassId)
    input_shortCut = input

    #First bottleneck Block
    left_b1 = bottleneck(input, num_bottleNeck_channels, hourGName + "__bottleNeck1")                #Image resolution: 64X64xnum_bottleNeck_channels
    b1_shortcut = bottleneck(left_b1, num_bottleNeck_channels, hourGName + "_bottleNeck1_shortcut")  #Image resolution: 64x64xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b1)                                       #Image resolution: 32x32xnum_bottleNeck_channels

    #Second bottleneck Block
    left_b2 = bottleneck(next, num_bottleNeck_channels, hourGName + "__bottleNeck2")                #Image resolution: 32x32xnum_bottleNeck_channels
    b2_shortcut = bottleneck(left_b2, num_bottleNeck_channels, hourGName + "_bottleNeck2_shortcut")  #Image resolution: 32x32xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b2)                                       #Image resolution: 16x16xnum_bottleNeck_channels

    #Third bottleneck Block
    left_b3 = bottleneck(next, num_bottleNeck_channels, hourGName + "__bottleNeck3")                #Image resolution: 16x16xnum_bottleNeck_channels
    b3_shortcut = bottleneck(left_b3, num_bottleNeck_channels, hourGName + "_bottleNeck3_shortcut")  #Image resolution: 16x16xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b3)                                       #Image resolution: 8x8xnum_bottleNeck_channels

    #forth bottleneck Block
    left_b4 = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck4")                 #Image resolution: 8x8xnum_bottleNeck_channels
    b4_shortcut = bottleneck(left_b4, num_bottleNeck_channels, hourGName + "_bottleNeck4_shortcut")  #Image resolution: 8x8xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b4)                                       #Image resolution: 4x4xnum_bottleNeck_channels TODO: Why not adding this max pooling?

    #creat bottom layer (3 consecutive bottlenecks)
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_1")            #Image resolution: 4x4xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_2")            #Image resolution: 4x4xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_3")            #Image resolution: 4x4xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 8x8xnum_bottleNeck_channels
    next = Add()([next, b4_shortcut])                                                               #Image resolution: 8x8xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_4")             #Image resolution: 8x8xnum_bottleNeck_channels
   
    next = UpSampling2D()(next)                                                                     #Image resolution: 16x16xnum_bottleNeck_channels
    next = Add()([next, b3_shortcut])                                                               #Image resolution: 16x16xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_3")             #Image resolution: 16x16xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 32x32xnum_bottleNeck_channels
    next = Add()([next, b2_shortcut])                                                               #Image resolution: 32x32xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_2")             #Image resolution: 32x32xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 64x64xnum_bottleNeck_channels
    next = Add()([next, b1_shortcut])                                                               #Image resolution: 64x64xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_1")             #Image resolution: 64x64xnum_bottleNeck_channels

    #Intermediate supervision
    next = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='relu',
                    name=str(hourGName) + '_Intermediate_conv_1x1_1')(next)                         #Image resolution: 64x64xnum_bottleNeck_channels
    
    next = BatchNormalization()(next)                                                                 #Image resolution: 64x64xnum_bottleNeck_channels
    heatMap = Conv2D(num_classes, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_heatMap_conv_1x1_1')(next)                 #Image resolution: 64x64xnum_classes

    # next = BatchNormalization(next)                                                               #Image resolution: 64x64xnum_bottleNeck_channels
    next = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_conv_1x1_2')(next)                         #Image resolution: 64x64xnum_bottleNeck_channels

    reMapedHeatMap = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_heatMap_conv_1x1_2')(heatMap)       #Image resolution: 64x64xnum_bottleNeck_channels
    outputHead = Add()([next,input_shortCut, reMapedHeatMap])

    return outputHead, heatMap
    
    
def stack_hourGlass_modules(num_classes, num_stacks, num_channels, input_shape):
    input = Input(shape=(input_shape[0], input_shape[1], 3))

    hourGlass_next = create_input_module(input, num_channels)                                      #Create hourGlass first input module to reduce the resolution to 64x64xnum_channels
    outputs = []

    for i in range(num_stacks):
        hourGlass_next, heatmap_loss = create_hourGlass_module(hourGlass_next, num_classes, num_channels, i)
        outputs.append(heatmap_loss)
    model = Model(inputs=input, outputs=outputs)

    return model

# %%
example_path = r"Cropped\Cropped\Cropped_384\ir_fm_f"
images_path = os.path.join(example_path,'color')
images_im, masks_im, keypoint_im = get_data(example_path)
images_im, masks_im, keypoint_im = data_shuffle(images_im, masks_im, keypoint_im)

# %%
display_picture_keypoints(images_path, keypoint_im,300)

# %%
images_im_cropped, images_im_cropped_resized= images_cropped(images_im, masks_im)

# %%
keypoint_im_256 = keypoint_im/1.5
fig, plot = plt.subplots()
for i in range(0,12,2):
    x = keypoint_im_256[0,i]
    y = keypoint_im_256[0,i+1]
    plot.scatter(x, y, 256, c="r", marker="+") # plot markers    
plot.set_xticks(())
plot.set_yticks(())
plt.imshow(images_im_cropped_resized[0]) # plot image # plot image
plt.tight_layout()
plt.show() # plot image
images_im_cropped_resized[0].shape
# Out:
# (256, 256, 3)

# %%
keypoints_im_gaussian = keypoints_to_gaussian(keypoint_im_256)

# %%
plt.imshow(keypoints_im_gaussian[1,:,:,1]) #example keypoint

# %%
prop_train = 0.8
Ntrain = int(images_im_cropped.shape[0]*prop_train)
X_tra, y_tra, X_val,y_val, y_val0 = images_im_cropped_resized[:Ntrain],keypoints_im_gaussian[:Ntrain],images_im_cropped_resized[Ntrain:],keypoints_im_gaussian[Ntrain:], keypoint_im_256[Ntrain:]


input_height, input_width = 256, 256
## output shape is the same as input
output_height, output_width = input_height, input_width 

nClasses = 9 # ironman

# %%
batch_size = 8
epochs = 50

model = stack_hourGlass_modules(9, 2, 256, (256,256))
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# batch_normalization_623 (BatchN (None, 256, 256, 3)  12          input_7[0][0]
# __________________________________________________________________________________________________
# input_conv_7x7_stride_2 (Conv2D (None, 128, 128, 64) 9472        batch_normalization_623[0][0]
# __________________________________________________________________________________________________
# batch_normalization_625 (BatchN (None, 128, 128, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 128, 128, 64) 4160        batch_normalization_625[0][0]
# __________________________________________________________________________________________________
# batch_normalization_626 (BatchN (None, 128, 128, 64) 256         input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_3x (None, 128, 128, 64) 36928       batch_normalization_626[0][0]
# __________________________________________________________________________________________________
# batch_normalization_624 (BatchN (None, 128, 128, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_627 (BatchN (None, 128, 128, 64) 256         input_module_bottlenec_1conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_1skip_co (None, 128, 128, 128 8320        batch_normalization_624[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 128, 128, 128 8320        batch_normalization_627[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1residua (None, 128, 128, 128 0           input_module_bottlenec_1skip_conn
#                                                                  input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# max_pooling2d_54 (MaxPooling2D) (None, 64, 64, 128)  0           input_module_bottlenec_1residual_
# __________________________________________________________________________________________________
# batch_normalization_628 (BatchN (None, 64, 64, 128)  512         max_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 64, 64, 64)   8256        batch_normalization_628[0][0]
# __________________________________________________________________________________________________
# batch_normalization_629 (BatchN (None, 64, 64, 64)   256         input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_3x (None, 64, 64, 64)   36928       batch_normalization_629[0][0]
# __________________________________________________________________________________________________
# batch_normalization_630 (BatchN (None, 64, 64, 64)   256         input_module_bottlenec_2conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 64, 64, 128)  8320        batch_normalization_630[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2residua (None, 64, 64, 128)  0           max_pooling2d_54[0][0]
#                                                                  input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_632 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 64, 64, 128)  16512       batch_normalization_632[0][0]
# __________________________________________________________________________________________________
# batch_normalization_633 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_3x (None, 64, 64, 128)  147584      batch_normalization_633[0][0]
# __________________________________________________________________________________________________
# batch_normalization_631 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# batch_normalization_634 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_3conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_3skip_co (None, 64, 64, 256)  33024       batch_normalization_631[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 64, 64, 256)  33024       batch_normalization_634[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3residua (None, 64, 64, 256)  0           input_module_bottlenec_3skip_conn
#                                                                  input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_635 (BatchN (None, 64, 64, 256)  1024        input_module_bottlenec_3residual_
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_1 (Con (None, 64, 64, 128)  32896       batch_normalization_635[0][0]
# __________________________________________________________________________________________________
# batch_normalization_636 (BatchN (None, 64, 64, 128)  512         hg0__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_3x3 (Conv2 (None, 64, 64, 128)  147584      batch_normalization_636[0][0]
# __________________________________________________________________________________________________
# batch_normalization_637 (BatchN (None, 64, 64, 128)  512         hg0__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_2 (Con (None, 64, 64, 256)  33024       batch_normalization_637[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1residual_output (None, 64, 64, 256)  0           input_module_bottlenec_3residual_
#                                                                  hg0__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_55 (MaxPooling2D) (None, 32, 32, 256)  0           hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_641 (BatchN (None, 32, 32, 256)  1024        max_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_1 (Con (None, 32, 32, 128)  32896       batch_normalization_641[0][0]
# __________________________________________________________________________________________________
# batch_normalization_642 (BatchN (None, 32, 32, 128)  512         hg0__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_3x3 (Conv2 (None, 32, 32, 128)  147584      batch_normalization_642[0][0]
# __________________________________________________________________________________________________
# batch_normalization_643 (BatchN (None, 32, 32, 128)  512         hg0__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_2 (Con (None, 32, 32, 256)  33024       batch_normalization_643[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2residual_output (None, 32, 32, 256)  0           max_pooling2d_55[0][0]
#                                                                  hg0__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_56 (MaxPooling2D) (None, 16, 16, 256)  0           hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_647 (BatchN (None, 16, 16, 256)  1024        max_pooling2d_56[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_1 (Con (None, 16, 16, 128)  32896       batch_normalization_647[0][0]
# __________________________________________________________________________________________________
# batch_normalization_648 (BatchN (None, 16, 16, 128)  512         hg0__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_3x3 (Conv2 (None, 16, 16, 128)  147584      batch_normalization_648[0][0]
# __________________________________________________________________________________________________
# batch_normalization_649 (BatchN (None, 16, 16, 128)  512         hg0__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_2 (Con (None, 16, 16, 256)  33024       batch_normalization_649[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3residual_output (None, 16, 16, 256)  0           max_pooling2d_56[0][0]
#                                                                  hg0__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_57 (MaxPooling2D) (None, 8, 8, 256)    0           hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_653 (BatchN (None, 8, 8, 256)    1024        max_pooling2d_57[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_1 (Conv (None, 8, 8, 128)    32896       batch_normalization_653[0][0]
# __________________________________________________________________________________________________
# batch_normalization_654 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_3x3 (Conv2D (None, 8, 8, 128)    147584      batch_normalization_654[0][0]
# __________________________________________________________________________________________________
# batch_normalization_655 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_2 (Conv (None, 8, 8, 256)    33024       batch_normalization_655[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4residual_output  (None, 8, 8, 256)    0           max_pooling2d_57[0][0]
#                                                                  hg0_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_58 (MaxPooling2D) (None, 4, 4, 256)    0           hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_659 (BatchN (None, 4, 4, 256)    1024        max_pooling2d_58[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_659[0][0]
# __________________________________________________________________________________________________
# batch_normalization_660 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_660[0][0]
# __________________________________________________________________________________________________
# batch_normalization_661 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_661[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1residual (None, 4, 4, 256)    0           max_pooling2d_58[0][0]
#                                                                  hg0_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_662 (BatchN (None, 4, 4, 256)    1024        hg0_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_662[0][0]
# __________________________________________________________________________________________________
# batch_normalization_663 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_663[0][0]
# __________________________________________________________________________________________________
# batch_normalization_664 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_664[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2residual (None, 4, 4, 256)    0           hg0_bottleNeck_bottom_1residual_o
#                                                                  hg0_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_665 (BatchN (None, 4, 4, 256)    1024        hg0_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_665[0][0]
# __________________________________________________________________________________________________
# batch_normalization_656 (BatchN (None, 8, 8, 256)    1024        hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_666 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 8, 8, 128)    32896       batch_normalization_656[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_666[0][0]
# __________________________________________________________________________________________________
# batch_normalization_657 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_667 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_3x (None, 8, 8, 128)    147584      batch_normalization_657[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_667[0][0]
# __________________________________________________________________________________________________
# batch_normalization_658 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3residual (None, 4, 4, 256)    0           hg0_bottleNeck_bottom_2residual_o
#                                                                  hg0_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 8, 8, 256)    33024       batch_normalization_658[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_48 (UpSampling2D) (None, 8, 8, 256)    0           hg0_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutresidua (None, 8, 8, 256)    0           hg0_bottleNeck4residual_output[0]
#                                                                  hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 8, 8, 256)    0           up_sampling2d_48[0][0]
#                                                                  hg0_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_668 (BatchN (None, 8, 8, 256)    1024        add_60[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 8, 8, 128)    32896       batch_normalization_668[0][0]
# __________________________________________________________________________________________________
# batch_normalization_650 (BatchN (None, 16, 16, 256)  1024        hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_669 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 16, 16, 128)  32896       batch_normalization_650[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_3x3  (None, 8, 8, 128)    147584      batch_normalization_669[0][0]
# __________________________________________________________________________________________________
# batch_normalization_651 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_670 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_3x (None, 16, 16, 128)  147584      batch_normalization_651[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 8, 8, 256)    33024       batch_normalization_670[0][0]
# __________________________________________________________________________________________________
# batch_normalization_652 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4residual_ (None, 8, 8, 256)    0           add_60[0][0]
#                                                                  hg0_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 16, 16, 256)  33024       batch_normalization_652[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_49 (UpSampling2D) (None, 16, 16, 256)  0           hg0_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutresidua (None, 16, 16, 256)  0           hg0__bottleNeck3residual_output[0
#                                                                  hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 16, 16, 256)  0           up_sampling2d_49[0][0]
#                                                                  hg0_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_671 (BatchN (None, 16, 16, 256)  1024        add_61[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 16, 16, 128)  32896       batch_normalization_671[0][0]
# __________________________________________________________________________________________________
# batch_normalization_644 (BatchN (None, 32, 32, 256)  1024        hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_672 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 32, 32, 128)  32896       batch_normalization_644[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_3x3  (None, 16, 16, 128)  147584      batch_normalization_672[0][0]
# __________________________________________________________________________________________________
# batch_normalization_645 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_673 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_3x (None, 32, 32, 128)  147584      batch_normalization_645[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 16, 16, 256)  33024       batch_normalization_673[0][0]
# __________________________________________________________________________________________________
# batch_normalization_646 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3residual_ (None, 16, 16, 256)  0           add_61[0][0]
#                                                                  hg0_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 32, 32, 256)  33024       batch_normalization_646[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_50 (UpSampling2D) (None, 32, 32, 256)  0           hg0_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutresidua (None, 32, 32, 256)  0           hg0__bottleNeck2residual_output[0
#                                                                  hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 32, 32, 256)  0           up_sampling2d_50[0][0]
#                                                                  hg0_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_674 (BatchN (None, 32, 32, 256)  1024        add_62[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 32, 32, 128)  32896       batch_normalization_674[0][0]
# __________________________________________________________________________________________________
# batch_normalization_638 (BatchN (None, 64, 64, 256)  1024        hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_675 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 64, 64, 128)  32896       batch_normalization_638[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_3x3  (None, 32, 32, 128)  147584      batch_normalization_675[0][0]
# __________________________________________________________________________________________________
# batch_normalization_639 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_676 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_3x (None, 64, 64, 128)  147584      batch_normalization_639[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 32, 32, 256)  33024       batch_normalization_676[0][0]
# __________________________________________________________________________________________________
# batch_normalization_640 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2residual_ (None, 32, 32, 256)  0           add_62[0][0]
#                                                                  hg0_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 64, 64, 256)  33024       batch_normalization_640[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_51 (UpSampling2D) (None, 64, 64, 256)  0           hg0_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutresidua (None, 64, 64, 256)  0           hg0__bottleNeck1residual_output[0
#                                                                  hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 64, 64, 256)  0           up_sampling2d_51[0][0]
#                                                                  hg0_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_677 (BatchN (None, 64, 64, 256)  1024        add_63[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 64, 64, 128)  32896       batch_normalization_677[0][0]
# __________________________________________________________________________________________________
# batch_normalization_678 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_3x3  (None, 64, 64, 128)  147584      batch_normalization_678[0][0]
# __________________________________________________________________________________________________
# batch_normalization_679 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 64, 64, 256)  33024       batch_normalization_679[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1residual_ (None, 64, 64, 256)  0           add_63[0][0]
#                                                                  hg0_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_1 (Co (None, 64, 64, 256)  65792       hg0_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_680 (BatchN (None, 64, 64, 256)  1024        hg0_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 64, 64, 9)    2313        batch_normalization_680[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_2 (Co (None, 64, 64, 256)  65792       batch_normalization_680[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 64, 64, 256)  2560        hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 64, 64, 256)  0           hg0_Intermediate_conv_1x1_2[0][0]
#                                                                  input_module_bottlenec_3residual_
#                                                                  hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# batch_normalization_681 (BatchN (None, 64, 64, 256)  1024        add_64[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_1 (Con (None, 64, 64, 128)  32896       batch_normalization_681[0][0]
# __________________________________________________________________________________________________
# batch_normalization_682 (BatchN (None, 64, 64, 128)  512         hg1__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_3x3 (Conv2 (None, 64, 64, 128)  147584      batch_normalization_682[0][0]
# __________________________________________________________________________________________________
# batch_normalization_683 (BatchN (None, 64, 64, 128)  512         hg1__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_2 (Con (None, 64, 64, 256)  33024       batch_normalization_683[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1residual_output (None, 64, 64, 256)  0           add_64[0][0]
#                                                                  hg1__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_59 (MaxPooling2D) (None, 32, 32, 256)  0           hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_687 (BatchN (None, 32, 32, 256)  1024        max_pooling2d_59[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_1 (Con (None, 32, 32, 128)  32896       batch_normalization_687[0][0]
# __________________________________________________________________________________________________
# batch_normalization_688 (BatchN (None, 32, 32, 128)  512         hg1__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_3x3 (Conv2 (None, 32, 32, 128)  147584      batch_normalization_688[0][0]
# __________________________________________________________________________________________________
# batch_normalization_689 (BatchN (None, 32, 32, 128)  512         hg1__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_2 (Con (None, 32, 32, 256)  33024       batch_normalization_689[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2residual_output (None, 32, 32, 256)  0           max_pooling2d_59[0][0]
#                                                                  hg1__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_60 (MaxPooling2D) (None, 16, 16, 256)  0           hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_693 (BatchN (None, 16, 16, 256)  1024        max_pooling2d_60[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_1 (Con (None, 16, 16, 128)  32896       batch_normalization_693[0][0]
# __________________________________________________________________________________________________
# batch_normalization_694 (BatchN (None, 16, 16, 128)  512         hg1__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_3x3 (Conv2 (None, 16, 16, 128)  147584      batch_normalization_694[0][0]
# __________________________________________________________________________________________________
# batch_normalization_695 (BatchN (None, 16, 16, 128)  512         hg1__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_2 (Con (None, 16, 16, 256)  33024       batch_normalization_695[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3residual_output (None, 16, 16, 256)  0           max_pooling2d_60[0][0]
#                                                                  hg1__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_61 (MaxPooling2D) (None, 8, 8, 256)    0           hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_699 (BatchN (None, 8, 8, 256)    1024        max_pooling2d_61[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_1 (Conv (None, 8, 8, 128)    32896       batch_normalization_699[0][0]
# __________________________________________________________________________________________________
# batch_normalization_700 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_3x3 (Conv2D (None, 8, 8, 128)    147584      batch_normalization_700[0][0]
# __________________________________________________________________________________________________
# batch_normalization_701 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_2 (Conv (None, 8, 8, 256)    33024       batch_normalization_701[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4residual_output  (None, 8, 8, 256)    0           max_pooling2d_61[0][0]
#                                                                  hg1_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_62 (MaxPooling2D) (None, 4, 4, 256)    0           hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_705 (BatchN (None, 4, 4, 256)    1024        max_pooling2d_62[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_705[0][0]
# __________________________________________________________________________________________________
# batch_normalization_706 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_706[0][0]
# __________________________________________________________________________________________________
# batch_normalization_707 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_707[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1residual (None, 4, 4, 256)    0           max_pooling2d_62[0][0]
#                                                                  hg1_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_708 (BatchN (None, 4, 4, 256)    1024        hg1_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_708[0][0]
# __________________________________________________________________________________________________
# batch_normalization_709 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_709[0][0]
# __________________________________________________________________________________________________
# batch_normalization_710 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_710[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2residual (None, 4, 4, 256)    0           hg1_bottleNeck_bottom_1residual_o
#                                                                  hg1_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_711 (BatchN (None, 4, 4, 256)    1024        hg1_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_711[0][0]
# __________________________________________________________________________________________________
# batch_normalization_702 (BatchN (None, 8, 8, 256)    1024        hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_712 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 8, 8, 128)    32896       batch_normalization_702[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_712[0][0]
# __________________________________________________________________________________________________
# batch_normalization_703 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_713 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_3x (None, 8, 8, 128)    147584      batch_normalization_703[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_713[0][0]
# __________________________________________________________________________________________________
# batch_normalization_704 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3residual (None, 4, 4, 256)    0           hg1_bottleNeck_bottom_2residual_o
#                                                                  hg1_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 8, 8, 256)    33024       batch_normalization_704[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_52 (UpSampling2D) (None, 8, 8, 256)    0           hg1_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutresidua (None, 8, 8, 256)    0           hg1_bottleNeck4residual_output[0]
#                                                                  hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 8, 8, 256)    0           up_sampling2d_52[0][0]
#                                                                  hg1_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_714 (BatchN (None, 8, 8, 256)    1024        add_65[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 8, 8, 128)    32896       batch_normalization_714[0][0]
# __________________________________________________________________________________________________
# batch_normalization_696 (BatchN (None, 16, 16, 256)  1024        hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_715 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 16, 16, 128)  32896       batch_normalization_696[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_3x3  (None, 8, 8, 128)    147584      batch_normalization_715[0][0]
# __________________________________________________________________________________________________
# batch_normalization_697 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_716 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_3x (None, 16, 16, 128)  147584      batch_normalization_697[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 8, 8, 256)    33024       batch_normalization_716[0][0]
# __________________________________________________________________________________________________
# batch_normalization_698 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4residual_ (None, 8, 8, 256)    0           add_65[0][0]
#                                                                  hg1_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 16, 16, 256)  33024       batch_normalization_698[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_53 (UpSampling2D) (None, 16, 16, 256)  0           hg1_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutresidua (None, 16, 16, 256)  0           hg1__bottleNeck3residual_output[0
#                                                                  hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 16, 16, 256)  0           up_sampling2d_53[0][0]
#                                                                  hg1_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_717 (BatchN (None, 16, 16, 256)  1024        add_66[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 16, 16, 128)  32896       batch_normalization_717[0][0]
# __________________________________________________________________________________________________
# batch_normalization_690 (BatchN (None, 32, 32, 256)  1024        hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_718 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 32, 32, 128)  32896       batch_normalization_690[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_3x3  (None, 16, 16, 128)  147584      batch_normalization_718[0][0]
# __________________________________________________________________________________________________
# batch_normalization_691 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_719 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_3x (None, 32, 32, 128)  147584      batch_normalization_691[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 16, 16, 256)  33024       batch_normalization_719[0][0]
# __________________________________________________________________________________________________
# batch_normalization_692 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3residual_ (None, 16, 16, 256)  0           add_66[0][0]
#                                                                  hg1_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 32, 32, 256)  33024       batch_normalization_692[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_54 (UpSampling2D) (None, 32, 32, 256)  0           hg1_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutresidua (None, 32, 32, 256)  0           hg1__bottleNeck2residual_output[0
#                                                                  hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 32, 32, 256)  0           up_sampling2d_54[0][0]
#                                                                  hg1_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_720 (BatchN (None, 32, 32, 256)  1024        add_67[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 32, 32, 128)  32896       batch_normalization_720[0][0]
# __________________________________________________________________________________________________
# batch_normalization_684 (BatchN (None, 64, 64, 256)  1024        hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_721 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 64, 64, 128)  32896       batch_normalization_684[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_3x3  (None, 32, 32, 128)  147584      batch_normalization_721[0][0]
# __________________________________________________________________________________________________
# batch_normalization_685 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_722 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_3x (None, 64, 64, 128)  147584      batch_normalization_685[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 32, 32, 256)  33024       batch_normalization_722[0][0]
# __________________________________________________________________________________________________
# batch_normalization_686 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2residual_ (None, 32, 32, 256)  0           add_67[0][0]
#                                                                  hg1_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 64, 64, 256)  33024       batch_normalization_686[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_55 (UpSampling2D) (None, 64, 64, 256)  0           hg1_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutresidua (None, 64, 64, 256)  0           hg1__bottleNeck1residual_output[0
#                                                                  hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 64, 64, 256)  0           up_sampling2d_55[0][0]
#                                                                  hg1_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_723 (BatchN (None, 64, 64, 256)  1024        add_68[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 64, 64, 128)  32896       batch_normalization_723[0][0]
# __________________________________________________________________________________________________
# batch_normalization_724 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_3x3  (None, 64, 64, 128)  147584      batch_normalization_724[0][0]
# __________________________________________________________________________________________________
# batch_normalization_725 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 64, 64, 256)  33024       batch_normalization_725[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1residual_ (None, 64, 64, 256)  0           add_68[0][0]
#                                                                  hg1_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_Intermediate_conv_1x1_1 (Co (None, 64, 64, 256)  65792       hg1_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_726 (BatchN (None, 64, 64, 256)  1024        hg1_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_Intermediate_heatMap_conv_1 (None, 64, 64, 9)    2313        batch_normalization_726[0][0]
# ==================================================================================================
# Total params: 7,028,126
# Trainable params: 6,994,328
# Non-trainable params: 33,798
# __________________________________________________________________________________________________

# %%
model.compile(loss='mse',optimizer="rmsprop",sample_weight_mode="temporal")
model.fit(X_tra,y_tra,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# Epoch 1/10
# 33/33 [==============================] - 964s 27s/step - loss: 1262.8788 - hg0_Intermediate_heatMap_conv_1x1_1_loss: 651.6006 - hg1_Intermediate_heatMap_conv_1x1_1_loss: 611.2782
# Epoch 2/10
#  3/33 [=>............................] - ETA: 13:24 - loss: 924.1121 - hg0_Intermediate_heatMap_conv_1x1_1_loss: 490.1094 - hg1_Intermediate_heatMap_conv_1x1_1_loss: 434.0027
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %%
output_height, output_width = 64, 64 
y_pred = model.predict(X_val)
y_pred = np.array(y_pred)
y_pred = y_pred.reshape(-1,output_height,output_width,nClasses)

Nlandmark = y_pred.shape[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5e7948bd3faa> in <module>
#       1 output_height, output_width = 64, 64
# ----> 2 y_pred = model.predict(X_val)
#       3 y_pred = numpy.array(y_pred)
#       4 y_pred = y_pred.reshape(-1,output_height,output_width,nClasses)
#       5
#
# NameError: name 'model' is not defined

# %%
display_predictions(X_val, y_pred, y_val)

# %% [markdown]
# Multimeter

# %%
example_path_mm = r"Dataset/Train_net/Synt/multimeter/Cropped/Cropped_384"
images_path_mm = os.path.join(example_path_mm,'color_back')
images_mm, masks_mm, keypoint_mm = get_data(example_path_mm, color_back=True)
images_mm, masks_mm, keypoint_mm = data_shuffle(images_mm, masks_mm, keypoint_mm)

# %%
display_picture_keypoints(images_path_mm, keypoint_mm,50)

# %%
images_mm_cropped, images_mm_cropped_resized= images_cropped(images_mm, masks_mm)

# %%
keypoint_mm_256 = keypoint_mm/1.5
fig, plot = plt.subplots()
for i in range(0,12,2):
    x = keypoint_mm_256[50,i]
    y = keypoint_mm_256[50,i+1]
    plot.scatter(x, y, 256, c="r", marker="+") # plot markers    
plot.set_xticks(())
plot.set_yticks(())
plt.imshow(images_mm_cropped_resized[50]) # plot image # plot image
plt.tight_layout()
plt.show() # plot image
images_mm_cropped_resized[50].shape
# Out:
# (256, 256, 3)

# %%
keypoints_mm_gaussian = keypoints_to_gaussian(keypoint_mm_256, size=5)

# %%
plt.imshow(keypoints_mm_gaussian[1,:,:,1]) #example keypoint

# %%
prop_train = 0.8
Ntrain_mm = int(images_mm_cropped.shape[0]*prop_train)
X_tra_mm, y_tra_mm, X_val_mm, y_val_mm, y_val0_mm = images_mm_cropped_resized[:Ntrain_mm],keypoints_mm_gaussian[:Ntrain_mm],images_mm_cropped_resized[Ntrain_mm:],keypoints_mm_gaussian[Ntrain_mm:], keypoint_mm_256[Ntrain_mm:]


input_height, input_width = 256, 256
output_height, output_width = 64, 64 

nClasses = 9 # ironman

# %%
batch_size = 8
epochs = 50

model_mm = stack_hourGlass_modules(9, 2, 256, (256,256))
model_mm.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 3)  12          input_1[0][0]
# __________________________________________________________________________________________________
# input_conv_7x7_stride_2 (Conv2D (None, 128, 128, 64) 9472        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 128, 128, 64) 4160        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_3x (None, 128, 128, 64) 36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 256         input_module_bottlenec_1conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_1skip_co (None, 128, 128, 128 8320        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 128, 128, 128 8320        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1residua (None, 128, 128, 128 0           input_module_bottlenec_1skip_conn
#                                                                  input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 128)  0           input_module_bottlenec_1residual_
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 128)  512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 64, 64, 64)   8256        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_3x (None, 64, 64, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         input_module_bottlenec_2conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 64, 64, 128)  8320        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2residua (None, 64, 64, 128)  0           max_pooling2d[0][0]
#                                                                  input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 128)  512         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 64, 64, 128)  16512       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 128)  512         input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_3x (None, 64, 64, 128)  147584      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 128)  512         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 128)  512         input_module_bottlenec_3conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_3skip_co (None, 64, 64, 256)  33024       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 64, 64, 256)  33024       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3residua (None, 64, 64, 256)  0           input_module_bottlenec_3skip_conn
#                                                                  input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 256)  1024        input_module_bottlenec_3residual_
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_1 (Con (None, 64, 64, 128)  32896       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 128)  512         hg0__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_3x3 (Conv2 (None, 64, 64, 128)  147584      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 128)  512         hg0__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_2 (Con (None, 64, 64, 256)  33024       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1residual_output (None, 64, 64, 256)  0           input_module_bottlenec_3residual_
#                                                                  hg0__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 256)  0           hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 256)  1024        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_1 (Con (None, 32, 32, 128)  32896       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 128)  512         hg0__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_3x3 (Conv2 (None, 32, 32, 128)  147584      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 128)  512         hg0__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_2 (Con (None, 32, 32, 256)  33024       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2residual_output (None, 32, 32, 256)  0           max_pooling2d_1[0][0]
#                                                                  hg0__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 256)  1024        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_1 (Con (None, 16, 16, 128)  32896       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 128)  512         hg0__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_3x3 (Conv2 (None, 16, 16, 128)  147584      batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 128)  512         hg0__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_2 (Con (None, 16, 16, 256)  33024       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3residual_output (None, 16, 16, 256)  0           max_pooling2d_2[0][0]
#                                                                  hg0__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 256)    1024        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_1 (Conv (None, 8, 8, 128)    32896       batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 128)    512         hg0_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_3x3 (Conv2D (None, 8, 8, 128)    147584      batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 128)    512         hg0_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_2 (Conv (None, 8, 8, 256)    33024       batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4residual_output  (None, 8, 8, 256)    0           max_pooling2d_3[0][0]
#                                                                  hg0_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 4, 4, 256)    1024        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1residual (None, 4, 4, 256)    0           max_pooling2d_4[0][0]
#                                                                  hg0_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 4, 4, 256)    1024        hg0_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2residual (None, 4, 4, 256)    0           hg0_bottleNeck_bottom_1residual_o
#                                                                  hg0_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 256)    1024        hg0_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 256)    1024        hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 8, 8, 128)    32896       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 128)    512         hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_3x (None, 8, 8, 128)    147584      batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 128)    512         hg0_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3residual (None, 4, 4, 256)    0           hg0_bottleNeck_bottom_2residual_o
#                                                                  hg0_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 8, 8, 256)    33024       batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 8, 8, 256)    0           hg0_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutresidua (None, 8, 8, 256)    0           hg0_bottleNeck4residual_output[0]
#                                                                  hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 256)    0           up_sampling2d[0][0]
#                                                                  hg0_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 256)    1024        add[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 8, 8, 128)    32896       batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 256)  1024        hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 128)    512         hg0_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 16, 16, 128)  32896       batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_3x3  (None, 8, 8, 128)    147584      batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 128)  512         hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 8, 8, 128)    512         hg0_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_3x (None, 16, 16, 128)  147584      batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 8, 8, 256)    33024       batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 128)  512         hg0_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4residual_ (None, 8, 8, 256)    0           add[0][0]
#                                                                  hg0_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 16, 16, 256)  33024       batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0           hg0_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutresidua (None, 16, 16, 256)  0           hg0__bottleNeck3residual_output[0
#                                                                  hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 256)  0           up_sampling2d_1[0][0]
#                                                                  hg0_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 256)  1024        add_1[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 16, 16, 128)  32896       batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 256)  1024        hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 128)  512         hg0_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 32, 32, 128)  32896       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_3x3  (None, 16, 16, 128)  147584      batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 128)  512         hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 128)  512         hg0_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_3x (None, 32, 32, 128)  147584      batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 16, 16, 256)  33024       batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 128)  512         hg0_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3residual_ (None, 16, 16, 256)  0           add_1[0][0]
#                                                                  hg0_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 32, 32, 256)  33024       batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           hg0_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutresidua (None, 32, 32, 256)  0           hg0__bottleNeck2residual_output[0
#                                                                  hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 256)  0           up_sampling2d_2[0][0]
#                                                                  hg0_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 256)  1024        add_2[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 32, 32, 128)  32896       batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32, 32, 128)  512         hg0_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 64, 64, 128)  32896       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_3x3  (None, 32, 32, 128)  147584      batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 128)  512         hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 128)  512         hg0_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_3x (None, 64, 64, 128)  147584      batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 32, 32, 256)  33024       batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 128)  512         hg0_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2residual_ (None, 32, 32, 256)  0           add_2[0][0]
#                                                                  hg0_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 64, 64, 256)  33024       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0           hg0_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutresidua (None, 64, 64, 256)  0           hg0__bottleNeck1residual_output[0
#                                                                  hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 256)  0           up_sampling2d_3[0][0]
#                                                                  hg0_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 64, 64, 256)  1024        add_3[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 64, 64, 128)  32896       batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 64, 64, 128)  512         hg0_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_3x3  (None, 64, 64, 128)  147584      batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64, 64, 128)  512         hg0_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 64, 64, 256)  33024       batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1residual_ (None, 64, 64, 256)  0           add_3[0][0]
#                                                                  hg0_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_1 (Co (None, 64, 64, 256)  65792       hg0_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 64, 64, 256)  1024        hg0_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 64, 64, 9)    2313        batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_2 (Co (None, 64, 64, 256)  65792       batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 64, 64, 256)  2560        hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 256)  0           hg0_Intermediate_conv_1x1_2[0][0]
#                                                                  input_module_bottlenec_3residual_
#                                                                  hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 64, 64, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_1 (Con (None, 64, 64, 128)  32896       batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 64, 64, 128)  512         hg1__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_3x3 (Conv2 (None, 64, 64, 128)  147584      batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 64, 64, 128)  512         hg1__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_2 (Con (None, 64, 64, 256)  33024       batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1residual_output (None, 64, 64, 256)  0           add_4[0][0]
#                                                                  hg1__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 256)  0           hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 256)  1024        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_1 (Con (None, 32, 32, 128)  32896       batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 128)  512         hg1__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_3x3 (Conv2 (None, 32, 32, 128)  147584      batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 128)  512         hg1__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_2 (Con (None, 32, 32, 256)  33024       batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2residual_output (None, 32, 32, 256)  0           max_pooling2d_5[0][0]
#                                                                  hg1__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 256)  0           hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 256)  1024        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_1 (Con (None, 16, 16, 128)  32896       batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 128)  512         hg1__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_3x3 (Conv2 (None, 16, 16, 128)  147584      batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 128)  512         hg1__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_2 (Con (None, 16, 16, 256)  33024       batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3residual_output (None, 16, 16, 256)  0           max_pooling2d_6[0][0]
#                                                                  hg1__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 256)    0           hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 256)    1024        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_1 (Conv (None, 8, 8, 128)    32896       batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 128)    512         hg1_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_3x3 (Conv2D (None, 8, 8, 128)    147584      batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 128)    512         hg1_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_2 (Conv (None, 8, 8, 256)    33024       batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4residual_output  (None, 8, 8, 256)    0           max_pooling2d_7[0][0]
#                                                                  hg1_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 256)    0           hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 4, 4, 256)    1024        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1residual (None, 4, 4, 256)    0           max_pooling2d_8[0][0]
#                                                                  hg1_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 4, 4, 256)    1024        hg1_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2residual (None, 4, 4, 256)    0           hg1_bottleNeck_bottom_1residual_o
#                                                                  hg1_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 4, 4, 256)    1024        hg1_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 256)    1024        hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 8, 8, 128)    32896       batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 128)    512         hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_3x (None, 8, 8, 128)    147584      batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 128)    512         hg1_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3residual (None, 4, 4, 256)    0           hg1_bottleNeck_bottom_2residual_o
#                                                                  hg1_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 8, 8, 256)    33024       batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 8, 8, 256)    0           hg1_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutresidua (None, 8, 8, 256)    0           hg1_bottleNeck4residual_output[0]
#                                                                  hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           up_sampling2d_4[0][0]
#                                                                  hg1_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 8, 8, 128)    32896       batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 256)  1024        hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 128)    512         hg1_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 16, 16, 128)  32896       batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_3x3  (None, 8, 8, 128)    147584      batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 128)  512         hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 128)    512         hg1_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_3x (None, 16, 16, 128)  147584      batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 8, 8, 256)    33024       batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 128)  512         hg1_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4residual_ (None, 8, 8, 256)    0           add_5[0][0]
#                                                                  hg1_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 16, 16, 256)  33024       batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 16, 16, 256)  0           hg1_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutresidua (None, 16, 16, 256)  0           hg1__bottleNeck3residual_output[0
#                                                                  hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 256)  0           up_sampling2d_5[0][0]
#                                                                  hg1_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 16, 16, 256)  1024        add_6[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 16, 16, 128)  32896       batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 256)  1024        hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 16, 16, 128)  512         hg1_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 32, 32, 128)  32896       batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_3x3  (None, 16, 16, 128)  147584      batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 128)  512         hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 16, 16, 128)  512         hg1_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_3x (None, 32, 32, 128)  147584      batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 16, 16, 256)  33024       batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 128)  512         hg1_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3residual_ (None, 16, 16, 256)  0           add_6[0][0]
#                                                                  hg1_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 32, 32, 256)  33024       batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 256)  0           hg1_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutresidua (None, 32, 32, 256)  0           hg1__bottleNeck2residual_output[0
#                                                                  hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 256)  0           up_sampling2d_6[0][0]
#                                                                  hg1_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 32, 32, 256)  1024        add_7[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 32, 32, 128)  32896       batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 256)  1024        hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 32, 32, 128)  512         hg1_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 64, 64, 128)  32896       batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_3x3  (None, 32, 32, 128)  147584      batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 64, 64, 128)  512         hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 32, 32, 128)  512         hg1_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_3x (None, 64, 64, 128)  147584      batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 32, 32, 256)  33024       batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 64, 64, 128)  512         hg1_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2residual_ (None, 32, 32, 256)  0           add_7[0][0]
#                                                                  hg1_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 64, 64, 256)  33024       batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 256)  0           hg1_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutresidua (None, 64, 64, 256)  0           hg1__bottleNeck1residual_output[0
#                                                                  hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 256)  0           up_sampling2d_7[0][0]
#                                                                  hg1_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 64, 64, 256)  1024        add_8[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 64, 64, 128)  32896       batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_3x3  (None, 64, 64, 128)  147584      batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 64, 64, 256)  33024       batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1residual_ (None, 64, 64, 256)  0           add_8[0][0]
#                                                                  hg1_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_Intermediate_conv_1x1_1 (Co (None, 64, 64, 256)  65792       hg1_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 64, 64, 256)  1024        hg1_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_Intermediate_heatMap_conv_1 (None, 64, 64, 9)    2313        batch_normalization_103[0][0]
# ==================================================================================================
# Total params: 7,028,126
# Trainable params: 6,994,328
# Non-trainable params: 33,798
# __________________________________________________________________________________________________

# %%
model_mm.compile(loss='mse',optimizer="rmsprop",sample_weight_mode="temporal")
model_mm.fit(X_tra_mm,y_tra_mm,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# 31/31 [==============================] - 513s 15s/step - loss: 584.7441 - hg0_Intermediate_heatMap_conv_1x1_1_loss: 293.3402 - hg1_Intermediate_heatMap_conv_1x1_1_loss: 291.4038

# %%
y_pred_mm = model_mm.predict(X_val_mm)
y_pred_mm = np.array(y_pred_mm)
y_pred_mm = y_pred_mm.reshape(-1,output_height,output_width,nClasses)

Nlandmark = y_pred_mm.shape[-1]

# %%
display_predictions(X_val_mm, y_pred_mm, y_val_mm)

# %% [markdown]
# DRILL

# %%
example_path_dr = r"Dataset/Train_net/Synt/duck/Cropped/Cropped_384"
images_path_dr = os.path.join(example_path_dr,'color_back')
images_dr, masks_dr, keypoint_dr = get_data(example_path_dr, color_back=True)
images_dr, masks_dr, keypoint_dr = data_shuffle(images_dr, masks_dr, keypoint_dr)

# %%
display_picture_keypoints(images_path_dr, keypoint_dr,208)

# %%
images_dr_cropped, images_dr_cropped_resized= images_cropped(images_dr, masks_dr)

# %%
keypoint_dr_256 = keypoint_dr/1.5
fig, plot = plt.subplots()
for i in range(0,12,2):
    x = keypoint_dr_256[208,i]
    y = keypoint_dr_256[208,i+1]
    plot.scatter(x, y, 256, c="r", marker="+") # plot markers    
plot.set_xticks(())
plot.set_yticks(())
plt.imshow(images_dr_cropped_resized[208]) # plot image # plot image
plt.tight_layout()
plt.show() # plot image
images_dr_cropped_resized[208].shape
# Out:
# (256, 256, 3)

# %%
keypoints_dr_gaussian = keypoints_to_gaussian(keypoint_dr_256)

# %%
plt.imshow(keypoints_dr_gaussian[1,:,:,1]) #example keypoint

# %%
Ntrain_dr = int(images_dr_cropped.shape[0]*prop_train)
X_tra_dr, y_tra_dr, X_val_dr, y_val_dr, y_val0_dr = images_dr_cropped_resized[:Ntrain_dr],keypoints_dr_gaussian[:Ntrain_dr],images_dr_cropped_resized[Ntrain_dr:],keypoints_dr_gaussian[Ntrain_dr:], keypoint_dr_256[Ntrain_dr:]


input_height, input_width = 256, 256
output_height, output_width = 64, 64 

nClasses = 9 # ironman

# %%
batch_size = 8
epochs = 50

model_dr = stack_hourGlass_modules(9, 2, 256, (256,256))
model_dr.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 256, 256, 3)  12          input_3[0][0]
# __________________________________________________________________________________________________
# input_conv_7x7_stride_2 (Conv2D (None, 128, 128, 64) 9472        batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 128, 128, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 128, 128, 64) 4160        batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 128, 128, 64) 256         input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_3x (None, 128, 128, 64) 36928       batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 128, 128, 64) 256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 128, 128, 64) 256         input_module_bottlenec_1conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_1skip_co (None, 128, 128, 128 8320        batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 128, 128, 128 8320        batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1residua (None, 128, 128, 128 0           input_module_bottlenec_1skip_conn
#                                                                  input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 64, 64, 128)  0           input_module_bottlenec_1residual_
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 64, 64, 128)  512         max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 64, 64, 64)   8256        batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 64, 64, 64)   256         input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_3x (None, 64, 64, 64)   36928       batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 64, 64, 64)   256         input_module_bottlenec_2conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 64, 64, 128)  8320        batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2residua (None, 64, 64, 128)  0           max_pooling2d_18[0][0]
#                                                                  input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 64, 64, 128)  16512       batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_3x (None, 64, 64, 128)  147584      batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 64, 64, 128)  512         input_module_bottlenec_3conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_3skip_co (None, 64, 64, 256)  33024       batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 64, 64, 256)  33024       batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3residua (None, 64, 64, 256)  0           input_module_bottlenec_3skip_conn
#                                                                  input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 64, 64, 256)  1024        input_module_bottlenec_3residual_
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_1 (Con (None, 64, 64, 128)  32896       batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 64, 64, 128)  512         hg0__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_3x3 (Conv2 (None, 64, 64, 128)  147584      batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 64, 64, 128)  512         hg0__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_2 (Con (None, 64, 64, 256)  33024       batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1residual_output (None, 64, 64, 256)  0           input_module_bottlenec_3residual_
#                                                                  hg0__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 32, 32, 256)  0           hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 32, 32, 256)  1024        max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_1 (Con (None, 32, 32, 128)  32896       batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 32, 32, 128)  512         hg0__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_3x3 (Conv2 (None, 32, 32, 128)  147584      batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 32, 32, 128)  512         hg0__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_2 (Con (None, 32, 32, 256)  33024       batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2residual_output (None, 32, 32, 256)  0           max_pooling2d_19[0][0]
#                                                                  hg0__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 16, 16, 256)  0           hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 16, 16, 256)  1024        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_1 (Con (None, 16, 16, 128)  32896       batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 16, 16, 128)  512         hg0__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_3x3 (Conv2 (None, 16, 16, 128)  147584      batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 16, 16, 128)  512         hg0__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_2 (Con (None, 16, 16, 256)  33024       batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3residual_output (None, 16, 16, 256)  0           max_pooling2d_20[0][0]
#                                                                  hg0__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 8, 8, 256)    0           hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 8, 8, 256)    1024        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_1 (Conv (None, 8, 8, 128)    32896       batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_3x3 (Conv2D (None, 8, 8, 128)    147584      batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_2 (Conv (None, 8, 8, 256)    33024       batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4residual_output  (None, 8, 8, 256)    0           max_pooling2d_21[0][0]
#                                                                  hg0_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 4, 4, 256)    0           hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 4, 4, 256)    1024        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1residual (None, 4, 4, 256)    0           max_pooling2d_22[0][0]
#                                                                  hg0_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 4, 4, 256)    1024        hg0_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2residual (None, 4, 4, 256)    0           hg0_bottleNeck_bottom_1residual_o
#                                                                  hg0_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 4, 4, 256)    1024        hg0_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 8, 8, 256)    1024        hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 8, 8, 128)    32896       batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_3x (None, 8, 8, 128)    147584      batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3residual (None, 4, 4, 256)    0           hg0_bottleNeck_bottom_2residual_o
#                                                                  hg0_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 8, 8, 256)    33024       batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 8, 8, 256)    0           hg0_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutresidua (None, 8, 8, 256)    0           hg0_bottleNeck4residual_output[0]
#                                                                  hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 8, 8, 256)    0           up_sampling2d_16[0][0]
#                                                                  hg0_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 8, 8, 256)    1024        add_20[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 8, 8, 128)    32896       batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 16, 16, 256)  1024        hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 16, 16, 128)  32896       batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_3x3  (None, 8, 8, 128)    147584      batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 8, 8, 128)    512         hg0_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_3x (None, 16, 16, 128)  147584      batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 8, 8, 256)    33024       batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4residual_ (None, 8, 8, 256)    0           add_20[0][0]
#                                                                  hg0_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 16, 16, 256)  33024       batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 16, 16, 256)  0           hg0_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutresidua (None, 16, 16, 256)  0           hg0__bottleNeck3residual_output[0
#                                                                  hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 16, 256)  0           up_sampling2d_17[0][0]
#                                                                  hg0_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 16, 16, 256)  1024        add_21[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 16, 16, 128)  32896       batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 32, 32, 256)  1024        hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 32, 32, 128)  32896       batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_3x3  (None, 16, 16, 128)  147584      batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 16, 16, 128)  512         hg0_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_3x (None, 32, 32, 128)  147584      batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 16, 16, 256)  33024       batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3residual_ (None, 16, 16, 256)  0           add_21[0][0]
#                                                                  hg0_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 32, 32, 256)  33024       batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 32, 32, 256)  0           hg0_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutresidua (None, 32, 32, 256)  0           hg0__bottleNeck2residual_output[0
#                                                                  hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 32, 32, 256)  0           up_sampling2d_18[0][0]
#                                                                  hg0_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 32, 32, 256)  1024        add_22[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 32, 32, 128)  32896       batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 64, 64, 256)  1024        hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 64, 64, 128)  32896       batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_3x3  (None, 32, 32, 128)  147584      batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 32, 32, 128)  512         hg0_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_3x (None, 64, 64, 128)  147584      batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 32, 32, 256)  33024       batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2residual_ (None, 32, 32, 256)  0           add_22[0][0]
#                                                                  hg0_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 64, 64, 256)  33024       batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 64, 64, 256)  0           hg0_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutresidua (None, 64, 64, 256)  0           hg0__bottleNeck1residual_output[0
#                                                                  hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 64, 64, 256)  0           up_sampling2d_19[0][0]
#                                                                  hg0_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 64, 64, 256)  1024        add_23[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 64, 64, 128)  32896       batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_3x3  (None, 64, 64, 128)  147584      batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 64, 64, 128)  512         hg0_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 64, 64, 256)  33024       batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1residual_ (None, 64, 64, 256)  0           add_23[0][0]
#                                                                  hg0_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_1 (Co (None, 64, 64, 256)  65792       hg0_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 64, 64, 256)  1024        hg0_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 64, 64, 9)    2313        batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_2 (Co (None, 64, 64, 256)  65792       batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 64, 64, 256)  2560        hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 64, 64, 256)  0           hg0_Intermediate_conv_1x1_2[0][0]
#                                                                  input_module_bottlenec_3residual_
#                                                                  hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 64, 64, 256)  1024        add_24[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_1 (Con (None, 64, 64, 128)  32896       batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 64, 64, 128)  512         hg1__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_3x3 (Conv2 (None, 64, 64, 128)  147584      batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 64, 64, 128)  512         hg1__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_2 (Con (None, 64, 64, 256)  33024       batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1residual_output (None, 64, 64, 256)  0           add_24[0][0]
#                                                                  hg1__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 32, 32, 256)  0           hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 32, 32, 256)  1024        max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_1 (Con (None, 32, 32, 128)  32896       batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 32, 32, 128)  512         hg1__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_3x3 (Conv2 (None, 32, 32, 128)  147584      batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 32, 32, 128)  512         hg1__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_2 (Con (None, 32, 32, 256)  33024       batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2residual_output (None, 32, 32, 256)  0           max_pooling2d_23[0][0]
#                                                                  hg1__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 16, 16, 256)  0           hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 16, 16, 256)  1024        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_1 (Con (None, 16, 16, 128)  32896       batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 16, 16, 128)  512         hg1__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_3x3 (Conv2 (None, 16, 16, 128)  147584      batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 16, 16, 128)  512         hg1__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_2 (Con (None, 16, 16, 256)  33024       batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3residual_output (None, 16, 16, 256)  0           max_pooling2d_24[0][0]
#                                                                  hg1__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 8, 8, 256)    0           hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 8, 8, 256)    1024        max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_1 (Conv (None, 8, 8, 128)    32896       batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_3x3 (Conv2D (None, 8, 8, 128)    147584      batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_2 (Conv (None, 8, 8, 256)    33024       batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4residual_output  (None, 8, 8, 256)    0           max_pooling2d_25[0][0]
#                                                                  hg1_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 4, 4, 256)    0           hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_290 (BatchN (None, 4, 4, 256)    1024        max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_291 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_291[0][0]
# __________________________________________________________________________________________________
# batch_normalization_292 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_292[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1residual (None, 4, 4, 256)    0           max_pooling2d_26[0][0]
#                                                                  hg1_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_293 (BatchN (None, 4, 4, 256)    1024        hg1_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_294 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_294[0][0]
# __________________________________________________________________________________________________
# batch_normalization_295 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_295[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2residual (None, 4, 4, 256)    0           hg1_bottleNeck_bottom_1residual_o
#                                                                  hg1_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 4, 4, 256)    1024        hg1_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 128)    32896       batch_normalization_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 8, 8, 256)    1024        hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 8, 8, 128)    32896       batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_3x3 (None, 4, 4, 128)    147584      batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# batch_normalization_288 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_3x (None, 8, 8, 128)    147584      batch_normalization_288[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 4, 4, 256)    33024       batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# batch_normalization_289 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3residual (None, 4, 4, 256)    0           hg1_bottleNeck_bottom_2residual_o
#                                                                  hg1_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 8, 8, 256)    33024       batch_normalization_289[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 8, 8, 256)    0           hg1_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutresidua (None, 8, 8, 256)    0           hg1_bottleNeck4residual_output[0]
#                                                                  hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 256)    0           up_sampling2d_20[0][0]
#                                                                  hg1_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 8, 8, 256)    1024        add_25[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 8, 8, 128)    32896       batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 16, 16, 256)  1024        hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 16, 16, 128)  32896       batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_3x3  (None, 8, 8, 128)    147584      batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 8, 8, 128)    512         hg1_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_3x (None, 16, 16, 128)  147584      batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 8, 8, 256)    33024       batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4residual_ (None, 8, 8, 256)    0           add_25[0][0]
#                                                                  hg1_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 16, 16, 256)  33024       batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 16, 16, 256)  0           hg1_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutresidua (None, 16, 16, 256)  0           hg1__bottleNeck3residual_output[0
#                                                                  hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 16, 16, 256)  0           up_sampling2d_21[0][0]
#                                                                  hg1_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, 16, 16, 256)  1024        add_26[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 16, 16, 128)  32896       batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 32, 32, 256)  1024        hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 32, 32, 128)  32896       batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_3x3  (None, 16, 16, 128)  147584      batch_normalization_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, 16, 16, 128)  512         hg1_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_3x (None, 32, 32, 128)  147584      batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 16, 16, 256)  33024       batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3residual_ (None, 16, 16, 256)  0           add_26[0][0]
#                                                                  hg1_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 32, 32, 256)  33024       batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 32, 32, 256)  0           hg1_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutresidua (None, 32, 32, 256)  0           hg1__bottleNeck2residual_output[0
#                                                                  hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 32, 32, 256)  0           up_sampling2d_22[0][0]
#                                                                  hg1_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, 32, 32, 256)  1024        add_27[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 32, 32, 128)  32896       batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 64, 64, 256)  1024        hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_306 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 64, 64, 128)  32896       batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_3x3  (None, 32, 32, 128)  147584      batch_normalization_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_307 (BatchN (None, 32, 32, 128)  512         hg1_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_3x (None, 64, 64, 128)  147584      batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 32, 32, 256)  33024       batch_normalization_307[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2residual_ (None, 32, 32, 256)  0           add_27[0][0]
#                                                                  hg1_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 64, 64, 256)  33024       batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 64, 64, 256)  0           hg1_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutresidua (None, 64, 64, 256)  0           hg1__bottleNeck1residual_output[0
#                                                                  hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 64, 64, 256)  0           up_sampling2d_23[0][0]
#                                                                  hg1_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 64, 64, 256)  1024        add_28[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 64, 64, 128)  32896       batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_3x3  (None, 64, 64, 128)  147584      batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 64, 64, 128)  512         hg1_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 64, 64, 256)  33024       batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1residual_ (None, 64, 64, 256)  0           add_28[0][0]
#                                                                  hg1_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_Intermediate_conv_1x1_1 (Co (None, 64, 64, 256)  65792       hg1_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, 64, 64, 256)  1024        hg1_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_Intermediate_heatMap_conv_1 (None, 64, 64, 9)    2313        batch_normalization_311[0][0]
# ==================================================================================================
# Total params: 7,028,126
# Trainable params: 6,994,328
# Non-trainable params: 33,798
# __________________________________________________________________________________________________

# %%
model_dr.compile(loss='mse',optimizer="rmsprop",sample_weight_mode="temporal")
model_dr.fit(X_tra_dr,y_tra_dr,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# 31/31 [==============================] - 514s 15s/step - loss: 1411.4475 - hg0_Intermediate_heatMap_conv_1x1_1_loss: 711.8303 - hg1_Intermediate_heatMap_conv_1x1_1_loss: 699.6172

# %%
y_pred_dr = model_dr.predict(X_val_dr)
y_pred_dr = np.array(y_pred_dr)
y_pred_dr = y_pred_dr.reshape(-1,output_height,output_width,nClasses)

Nlandmark = y_pred_dr.shape[-1]

# %%
display_predictions(X_val_dr, y_pred_dr, y_val_dr)
