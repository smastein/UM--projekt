# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import matplotlib.pyplot as plt
import tensorflow as tf
import keras, sys, time, os, warnings, cv2

from keras.models import *
from keras.layers import *

import numpy as np
import pandas as pd 

import glob
import os
import pickle as pkl
import datetime

from keras.optimizers import RMSprop
from keras.callbacks import CSVLogger, ModelCheckpoint
from keras.models import load_model, model_from_json
from keras.losses import mean_squared_error

from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import UpSampling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Activation
from keras.layers import Add
from keras.models import Input
from keras.models import Model

from skimage.transform import resize

# %%
def get_data(path):
    images = []
    masks = []
    keypoints = None
    for subdir, dirs, files in os.walk(path):
        for filename in files:
            filepath = subdir + os.sep + filename
            if filepath.endswith(".jpg") or filepath.endswith(".png") and 'color' in filepath and 'color_back' not in filepath:
                img = cv2.imread(filepath)
                images.append(img)
            if filepath.endswith(".jpg") or filepath.endswith(".png") and 'mask' in filepath :
                img = cv2.imread(filepath)
                masks.append(img)
            if 'keypoints' in filename:
                keypoints = pd.read_csv(filepath, delim_whitespace=True, header=None)
                keypoints = np.array(keypoints)
    masks = np.array(masks)
    images = np.array(images)
    return images, masks, keypoints

def gaussian_k(x0,y0,sigma, width, height):
        """ Make a square gaussian kernel centered at (x0, y0) with sigma as SD.
        """
        x = np.arange(0, width, 1, float) ## (width,)
        y = np.arange(0, height, 1, float)[:, np.newaxis] ## (height,1)
        return np.exp(-((x-x0)**2 + (y-y0)**2) / (2*sigma**2))

# %%
example_path = r"Cropped\Cropped\Cropped_384\ir_fm_f"
images_path = os.path.join(example_path,'color')
images_im, masks_im, keypoint_im = get_data(example_path)
to_shuffle = list(zip(images_im, masks_im, keypoint_im))
images_im, masks_im, keypoint_im = zip(*to_shuffle)
images_im = np.array(images_im)
masks_im = np.array(masks_im)
keypoint_im = np.array(keypoint_im)
prop_train = 0.8
Ntrain = int(images_im.shape[0]*prop_train)
i_train_im, m_train_im, i_val_im, m_val_im  = images_im[:Ntrain], masks_im[:Ntrain], images_im[Ntrain:], masks_im[Ntrain:]

# %%
counter = 0
keypoint_nr = 0
for subdir, dirs, files in os.walk(images_path):
    for filename in files:
        filepath = subdir + os.sep + filename
        if filepath.endswith(".jpg") or filepath.endswith(".png") and counter == keypoint_nr:
            img = cv2.imread(filepath)
            fig, plot = plt.subplots()
            for i in range(0,12,2):
                x = keypoint_im[keypoint_nr,i]
                y = keypoint_im[keypoint_nr,i+1]
                plot.scatter(x, y, 256, c="r", marker="+") # plot markers    
            plot.set_xticks(())
            plot.set_yticks(())
            plt.imshow(img, cmap="gray") # plot image
            plt.tight_layout()
            plt.show()
            keypoint_nr = keypoint_nr + 1
            break
        counter = counter + 1

# %%
masks_im[0,0,0]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
images_im_cropped=np.empty_like(images_im)
images_im_cropped_resized=np.empty((images_im.shape[0],128,128,3))

for i in range(len(images_im)):
    for x in range(384):
        for y in range(384):
            images_im_cropped[i,x,y] = images_im[i,x,y] * masks_im[i,x,y,]  
    im = resize(images_im_cropped[i],(int(384/3),int(384/3)),1)
    images_im_cropped_resized[i] = im

# %%
keypoint_im_128 = keypoint_im/3
fig, plot = plt.subplots()
for i in range(0,12,2):
    x = keypoint_im_128[0,i]
    y = keypoint_im_128[0,i+1]
    plot.scatter(x, y, 128, c="r", marker="+") # plot markers    
plot.set_xticks(())
plot.set_yticks(())
plt.imshow(images_im_cropped_resized[0]) # plot image # plot image
plt.tight_layout()
plt.show() # plot image
images_im_cropped_resized[0].shape
# Out:
# (128, 128, 3)

# %%
keypoints_im_gaussian = []
for k in keypoint_im_128:
    image_kp = []
    for x in range(0,18,2):
        size = 20
        kp=np.zeros((int(384/3),int(384/3)))
        g = gaussian_k(size/2,size/2,4,size,size)
        kp[int(k[x]-size/2):int(k[x]+size/2),int(k[x+1]-size/2):int(k[x+1]+size/2)] = g
        image_kp.append(kp*255)

    keypoints_im_gaussian.append(np.array(image_kp).T)
keypoints_im_gaussian = np.array(keypoints_im_gaussian)

# %%
plt.imshow(keypoints_im_gaussian[1,:,:,1]) #example keypoint

# %%
prop_train = 0.8
Ntrain = int(images_im_cropped.shape[0]*prop_train)
X_tra, y_tra, X_val,y_val, y_val0 = images_im_cropped_resized[:Ntrain],keypoints_im_gaussian[:Ntrain],images_im_cropped_resized[Ntrain:],keypoints_im_gaussian[Ntrain:], keypoint_im_128[Ntrain:]
#del X_train, y_train

input_height, input_width = 128, 128
## output shape is the same as input
output_height, output_width = input_height, input_width 

nClasses = 9 # ironman

# %%
def bottleneck(input, channels, name):
    shortcut = input
    #Make input channels same as output channel if the input has different number of channels, so we can add input with the output of last part of residual block
    if shortcut.shape[-1] != channels:
        shortcut = BatchNormalization()(shortcut)
        shortcut = Conv2D(channels,(1,1), padding="same", activation='relu', name=name + "skip_connection")(shortcut)

    #bottleneck block

    #First conv 1x1
    next = BatchNormalization()(input)
    next = Conv2D(channels//2,(1,1), padding="same", activation='relu', name=name + "conv_1x1_1")(next)

    #Second conv 3x3
    next = BatchNormalization()(next)
    next = Conv2D(channels//2,(3,3), padding="same", activation='relu', name=name + "conv_3x3")(next)

    #Third conv 1x1
    next = BatchNormalization()(next)
    next = Conv2D(channels,(1,1), padding="same", activation='relu', name=name + "conv_1x1_2")(next)

    next = Add(name=name + "residual_output")([shortcut, next])

    return next

def create_input_module(input, num_channels):
    #conv2D with strite 2, filter size 7x7 and padding of same results 1/2 resolution
    #maxpooling results into another 1/2 of resolution

    next = BatchNormalization()(input)                                                             #Image resolution: 256x256xnum_channels
    next = Conv2D(64,(7,7), padding="same", activation='relu', strides=(2,2), name="input_conv_7x7_stride_2")(next) #Image resolution: 128x128xnum_channels TODO: why not num_channels?

    next = bottleneck(next, num_channels//2,"input_module_bottlenec_1")                          #Image resolution: 128x128xnum_channels TODO: Why num_bottleNeck_channels//2
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(next)                                       #Image resolution: 64x64xnum_channels

    next = bottleneck(next, num_channels//2, "input_module_bottlenec_2")                         #Image resolution: 64x64xnum_channels TODO: Why num_bottleNeck_channels//2
    next = bottleneck(next, num_channels, "input_module_bottlenec_3")                            #Image resolution: 64x64xnum_channels

    return next

def create_hourGlass_module(input, num_classes, num_bottleNeck_channels, hourGlassId):
    hourGName = "hg" + str(hourGlassId)
    input_shortCut = input

    #First bottleneck Block
    left_b1 = bottleneck(input, num_bottleNeck_channels, hourGName + "__bottleNeck1")                #Image resolution: 64X64xnum_bottleNeck_channels
    b1_shortcut = bottleneck(left_b1, num_bottleNeck_channels, hourGName + "_bottleNeck1_shortcut")  #Image resolution: 64x64xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b1)                                       #Image resolution: 32x32xnum_bottleNeck_channels

    #Second bottleneck Block
    left_b2 = bottleneck(next, num_bottleNeck_channels, hourGName + "__bottleNeck2")                #Image resolution: 32x32xnum_bottleNeck_channels
    b2_shortcut = bottleneck(left_b2, num_bottleNeck_channels, hourGName + "_bottleNeck2_shortcut")  #Image resolution: 32x32xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b2)                                       #Image resolution: 16x16xnum_bottleNeck_channels

    #Third bottleneck Block
    left_b3 = bottleneck(next, num_bottleNeck_channels, hourGName + "__bottleNeck3")                #Image resolution: 16x16xnum_bottleNeck_channels
    b3_shortcut = bottleneck(left_b3, num_bottleNeck_channels, hourGName + "_bottleNeck3_shortcut")  #Image resolution: 16x16xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b3)                                       #Image resolution: 8x8xnum_bottleNeck_channels

    #forth bottleneck Block
    left_b4 = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck4")                 #Image resolution: 8x8xnum_bottleNeck_channels
    b4_shortcut = bottleneck(left_b4, num_bottleNeck_channels, hourGName + "_bottleNeck4_shortcut")  #Image resolution: 8x8xnum_bottleNeck_channels
    next = MaxPool2D(pool_size=(2,2), strides=(2,2))(left_b4)                                       #Image resolution: 4x4xnum_bottleNeck_channels TODO: Why not adding this max pooling?

    #creat bottom layer (3 consecutive bottlenecks)
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_1")            #Image resolution: 4x4xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_2")            #Image resolution: 4x4xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_bottom_3")            #Image resolution: 4x4xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 8x8xnum_bottleNeck_channels
    next = Add()([next, b4_shortcut])                                                               #Image resolution: 8x8xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_4")             #Image resolution: 8x8xnum_bottleNeck_channels
   
    next = UpSampling2D()(next)                                                                     #Image resolution: 16x16xnum_bottleNeck_channels
    next = Add()([next, b3_shortcut])                                                               #Image resolution: 16x16xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_3")             #Image resolution: 16x16xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 32x32xnum_bottleNeck_channels
    next = Add()([next, b2_shortcut])                                                               #Image resolution: 32x32xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_2")             #Image resolution: 32x32xnum_bottleNeck_channels

    next = UpSampling2D()(next)                                                                     #Image resolution: 64x64xnum_bottleNeck_channels
    next = Add()([next, b1_shortcut])                                                               #Image resolution: 64x64xnum_bottleNeck_channels
    next = bottleneck(next, num_bottleNeck_channels, hourGName + "_bottleNeck_right_1")             #Image resolution: 64x64xnum_bottleNeck_channels

    #Intermediate supervision
    next = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='relu',
                    name=str(hourGName) + '_Intermediate_conv_1x1_1')(next)                         #Image resolution: 64x64xnum_bottleNeck_channels
    
    next = BatchNormalization()(next)                                                                 #Image resolution: 64x64xnum_bottleNeck_channels
    heatMap = Conv2D(num_classes, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_heatMap_conv_1x1_1')(next)                 #Image resolution: 64x64xnum_classes

    # next = BatchNormalization(next)                                                               #Image resolution: 64x64xnum_bottleNeck_channels
    next = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_conv_1x1_2')(next)                         #Image resolution: 64x64xnum_bottleNeck_channels

    reMapedHeatMap = Conv2D(num_bottleNeck_channels, kernel_size=(1, 1), padding='same', activation='linear',
                    name=str(hourGName) + '_Intermediate_heatMap_conv_1x1_2')(heatMap)       #Image resolution: 64x64xnum_bottleNeck_channels
    outputHead = Add()([next,input_shortCut, reMapedHeatMap])

    return outputHead, heatMap
    
    
def stack_hourGlass_modules(num_classes, num_stacks, num_channels, input_shape):
    input = Input(shape=(input_shape[0], input_shape[1], 3))

    hourGlass_next = create_input_module(input, num_channels)                                      #Create hourGlass first input module to reduce the resolution to 64x64xnum_channels
    outputs = []

    for i in range(num_stacks):
        hourGlass_next, heatmap_loss = create_hourGlass_module(hourGlass_next, num_classes, num_channels, i)
        outputs.append(heatmap_loss)
    model = Model(inputs=input, outputs=outputs)

    return model

# %%
batch_size = 8
epochs = 50

model = stack_hourGlass_modules(3, 2, 128, (128,128))
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 128, 128, 3)  12          input_3[0][0]
# __________________________________________________________________________________________________
# input_conv_7x7_stride_2 (Conv2D (None, 64, 64, 64)   9472        batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 64, 64, 64)   256         input_conv_7x7_stride_2[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 64, 64, 32)   2080        batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 64, 64, 32)   128         input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_3x (None, 64, 64, 32)   9248        batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 64, 64, 32)   128         input_module_bottlenec_1conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_1conv_1x (None, 64, 64, 64)   2112        batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_1residua (None, 64, 64, 64)   0           input_conv_7x7_stride_2[0][0]
#                                                                  input_module_bottlenec_1conv_1x1_
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 32, 32, 64)   0           input_module_bottlenec_1residual_
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 32, 32, 64)   256         max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 32, 32, 32)   2080        batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 32, 32, 32)   128         input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_3x (None, 32, 32, 32)   9248        batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 32, 32, 32)   128         input_module_bottlenec_2conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_2conv_1x (None, 32, 32, 64)   2112        batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_2residua (None, 32, 32, 64)   0           max_pooling2d_18[0][0]
#                                                                  input_module_bottlenec_2conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 32, 32, 64)   256         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 32, 32, 64)   4160        batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 32, 32, 64)   256         input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_3x (None, 32, 32, 64)   36928       batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 32, 32, 64)   256         input_module_bottlenec_2residual_
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 32, 32, 64)   256         input_module_bottlenec_3conv_3x3[
# __________________________________________________________________________________________________
# input_module_bottlenec_3skip_co (None, 32, 32, 128)  8320        batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3conv_1x (None, 32, 32, 128)  8320        batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# input_module_bottlenec_3residua (None, 32, 32, 128)  0           input_module_bottlenec_3skip_conn
#                                                                  input_module_bottlenec_3conv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 32, 32, 128)  512         input_module_bottlenec_3residual_
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_1 (Con (None, 32, 32, 64)   8256        batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 32, 32, 64)   256         hg0__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_3x3 (Conv2 (None, 32, 32, 64)   36928       batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 32, 32, 64)   256         hg0__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1conv_1x1_2 (Con (None, 32, 32, 128)  8320        batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck1residual_output (None, 32, 32, 128)  0           input_module_bottlenec_3residual_
#                                                                  hg0__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 16, 128)  0           hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 16, 16, 128)  512         max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_1 (Con (None, 16, 16, 64)   8256        batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 16, 16, 64)   256         hg0__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_3x3 (Conv2 (None, 16, 16, 64)   36928       batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 16, 16, 64)   256         hg0__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2conv_1x1_2 (Con (None, 16, 16, 128)  8320        batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck2residual_output (None, 16, 16, 128)  0           max_pooling2d_19[0][0]
#                                                                  hg0__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 8, 8, 128)    0           hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 8, 8, 128)    512         max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_1 (Con (None, 8, 8, 64)     8256        batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 8, 8, 64)     256         hg0__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_3x3 (Conv2 (None, 8, 8, 64)     36928       batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 8, 8, 64)     256         hg0__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3conv_1x1_2 (Con (None, 8, 8, 128)    8320        batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# hg0__bottleNeck3residual_output (None, 8, 8, 128)    0           max_pooling2d_20[0][0]
#                                                                  hg0__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 4, 4, 128)    0           hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 4, 4, 128)    512         max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_1 (Conv (None, 4, 4, 64)     8256        batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 4, 4, 64)     256         hg0_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_3x3 (Conv2D (None, 4, 4, 64)     36928       batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 4, 4, 64)     256         hg0_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4conv_1x1_2 (Conv (None, 4, 4, 128)    8320        batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck4residual_output  (None, 4, 4, 128)    0           max_pooling2d_21[0][0]
#                                                                  hg0_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 2, 2, 128)    0           hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 2, 2, 128)    512         max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 2, 2, 64)     8256        batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 2, 2, 64)     256         hg0_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_3x3 (None, 2, 2, 64)     36928       batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 2, 2, 64)     256         hg0_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1conv_1x1 (None, 2, 2, 128)    8320        batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_1residual (None, 2, 2, 128)    0           max_pooling2d_22[0][0]
#                                                                  hg0_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 2, 2, 128)    512         hg0_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 2, 2, 64)     8256        batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 2, 2, 64)     256         hg0_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_3x3 (None, 2, 2, 64)     36928       batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 2, 2, 64)     256         hg0_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2conv_1x1 (None, 2, 2, 128)    8320        batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_2residual (None, 2, 2, 128)    0           hg0_bottleNeck_bottom_1residual_o
#                                                                  hg0_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 2, 2, 128)    512         hg0_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 2, 2, 64)     8256        batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 4, 4, 128)    512         hg0_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 2, 2, 64)     256         hg0_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 4, 4, 64)     8256        batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_3x3 (None, 2, 2, 64)     36928       batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 4, 4, 64)     256         hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 2, 2, 64)     256         hg0_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_3x (None, 4, 4, 64)     36928       batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3conv_1x1 (None, 2, 2, 128)    8320        batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 4, 4, 64)     256         hg0_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_bottom_3residual (None, 2, 2, 128)    0           hg0_bottleNeck_bottom_2residual_o
#                                                                  hg0_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutconv_1x (None, 4, 4, 128)    8320        batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 4, 4, 128)    0           hg0_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg0_bottleNeck4_shortcutresidua (None, 4, 4, 128)    0           hg0_bottleNeck4residual_output[0]
#                                                                  hg0_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 4, 4, 128)    0           up_sampling2d_16[0][0]
#                                                                  hg0_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 4, 4, 128)    512         add_20[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 4, 4, 64)     8256        batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 8, 8, 128)    512         hg0__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 4, 4, 64)     256         hg0_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 8, 8, 64)     8256        batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_3x3  (None, 4, 4, 64)     36928       batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 8, 8, 64)     256         hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 4, 4, 64)     256         hg0_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_3x (None, 8, 8, 64)     36928       batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4conv_1x1_ (None, 4, 4, 128)    8320        batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 8, 8, 64)     256         hg0_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_4residual_ (None, 4, 4, 128)    0           add_20[0][0]
#                                                                  hg0_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutconv_1x (None, 8, 8, 128)    8320        batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 8, 8, 128)    0           hg0_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck3_shortcutresidua (None, 8, 8, 128)    0           hg0__bottleNeck3residual_output[0
#                                                                  hg0_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 8, 8, 128)    0           up_sampling2d_17[0][0]
#                                                                  hg0_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 8, 8, 128)    512         add_21[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 8, 8, 64)     8256        batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 16, 16, 128)  512         hg0__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 8, 8, 64)     256         hg0_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 16, 16, 64)   8256        batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_3x3  (None, 8, 8, 64)     36928       batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 16, 16, 64)   256         hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 8, 8, 64)     256         hg0_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_3x (None, 16, 16, 64)   36928       batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3conv_1x1_ (None, 8, 8, 128)    8320        batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 16, 16, 64)   256         hg0_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_3residual_ (None, 8, 8, 128)    0           add_21[0][0]
#                                                                  hg0_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutconv_1x (None, 16, 16, 128)  8320        batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 16, 16, 128)  0           hg0_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck2_shortcutresidua (None, 16, 16, 128)  0           hg0__bottleNeck2residual_output[0
#                                                                  hg0_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 128)  0           up_sampling2d_18[0][0]
#                                                                  hg0_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 16, 16, 128)  512         add_22[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 16, 16, 64)   8256        batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 32, 32, 128)  512         hg0__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 16, 16, 64)   256         hg0_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 32, 32, 64)   8256        batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_3x3  (None, 16, 16, 64)   36928       batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 32, 32, 64)   256         hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 16, 16, 64)   256         hg0_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_3x (None, 32, 32, 64)   36928       batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2conv_1x1_ (None, 16, 16, 128)  8320        batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 32, 32, 64)   256         hg0_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_2residual_ (None, 16, 16, 128)  0           add_22[0][0]
#                                                                  hg0_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutconv_1x (None, 32, 32, 128)  8320        batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 32, 32, 128)  0           hg0_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg0_bottleNeck1_shortcutresidua (None, 32, 32, 128)  0           hg0__bottleNeck1residual_output[0
#                                                                  hg0_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 32, 32, 128)  0           up_sampling2d_19[0][0]
#                                                                  hg0_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 32, 32, 128)  512         add_23[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 32, 32, 64)   8256        batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 32, 32, 64)   256         hg0_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_3x3  (None, 32, 32, 64)   36928       batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 32, 32, 64)   256         hg0_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1conv_1x1_ (None, 32, 32, 128)  8320        batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# hg0_bottleNeck_right_1residual_ (None, 32, 32, 128)  0           add_23[0][0]
#                                                                  hg0_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_1 (Co (None, 32, 32, 128)  16512       hg0_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 32, 32, 128)  512         hg0_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 32, 32, 3)    387         batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_conv_1x1_2 (Co (None, 32, 32, 128)  16512       batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# hg0_Intermediate_heatMap_conv_1 (None, 32, 32, 128)  512         hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 32, 32, 128)  0           hg0_Intermediate_conv_1x1_2[0][0]
#                                                                  input_module_bottlenec_3residual_
#                                                                  hg0_Intermediate_heatMap_conv_1x1
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 32, 32, 128)  512         add_24[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_1 (Con (None, 32, 32, 64)   8256        batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 32, 32, 64)   256         hg1__bottleNeck1conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_3x3 (Conv2 (None, 32, 32, 64)   36928       batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 32, 32, 64)   256         hg1__bottleNeck1conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1conv_1x1_2 (Con (None, 32, 32, 128)  8320        batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck1residual_output (None, 32, 32, 128)  0           add_24[0][0]
#                                                                  hg1__bottleNeck1conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 16, 16, 128)  0           hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 16, 16, 128)  512         max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_1 (Con (None, 16, 16, 64)   8256        batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 16, 16, 64)   256         hg1__bottleNeck2conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_3x3 (Conv2 (None, 16, 16, 64)   36928       batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 16, 16, 64)   256         hg1__bottleNeck2conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2conv_1x1_2 (Con (None, 16, 16, 128)  8320        batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck2residual_output (None, 16, 16, 128)  0           max_pooling2d_23[0][0]
#                                                                  hg1__bottleNeck2conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 8, 8, 128)    0           hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 8, 8, 128)    512         max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_1 (Con (None, 8, 8, 64)     8256        batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 8, 8, 64)     256         hg1__bottleNeck3conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_3x3 (Conv2 (None, 8, 8, 64)     36928       batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 8, 8, 64)     256         hg1__bottleNeck3conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3conv_1x1_2 (Con (None, 8, 8, 128)    8320        batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# hg1__bottleNeck3residual_output (None, 8, 8, 128)    0           max_pooling2d_24[0][0]
#                                                                  hg1__bottleNeck3conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 4, 4, 128)    0           hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 4, 4, 128)    512         max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_1 (Conv (None, 4, 4, 64)     8256        batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 4, 4, 64)     256         hg1_bottleNeck4conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_3x3 (Conv2D (None, 4, 4, 64)     36928       batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 4, 4, 64)     256         hg1_bottleNeck4conv_3x3[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4conv_1x1_2 (Conv (None, 4, 4, 128)    8320        batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck4residual_output  (None, 4, 4, 128)    0           max_pooling2d_25[0][0]
#                                                                  hg1_bottleNeck4conv_1x1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 2, 2, 128)    0           hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_289 (BatchN (None, 2, 2, 128)    512         max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 2, 2, 64)     8256        batch_normalization_289[0][0]
# __________________________________________________________________________________________________
# batch_normalization_290 (BatchN (None, 2, 2, 64)     256         hg1_bottleNeck_bottom_1conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_3x3 (None, 2, 2, 64)     36928       batch_normalization_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_291 (BatchN (None, 2, 2, 64)     256         hg1_bottleNeck_bottom_1conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1conv_1x1 (None, 2, 2, 128)    8320        batch_normalization_291[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_1residual (None, 2, 2, 128)    0           max_pooling2d_26[0][0]
#                                                                  hg1_bottleNeck_bottom_1conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_292 (BatchN (None, 2, 2, 128)    512         hg1_bottleNeck_bottom_1residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 2, 2, 64)     8256        batch_normalization_292[0][0]
# __________________________________________________________________________________________________
# batch_normalization_293 (BatchN (None, 2, 2, 64)     256         hg1_bottleNeck_bottom_2conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_3x3 (None, 2, 2, 64)     36928       batch_normalization_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_294 (BatchN (None, 2, 2, 64)     256         hg1_bottleNeck_bottom_2conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2conv_1x1 (None, 2, 2, 128)    8320        batch_normalization_294[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_2residual (None, 2, 2, 128)    0           hg1_bottleNeck_bottom_1residual_o
#                                                                  hg1_bottleNeck_bottom_2conv_1x1_2
# __________________________________________________________________________________________________
# batch_normalization_295 (BatchN (None, 2, 2, 128)    512         hg1_bottleNeck_bottom_2residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 2, 2, 64)     8256        batch_normalization_295[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 4, 4, 128)    512         hg1_bottleNeck4residual_output[0]
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 2, 2, 64)     256         hg1_bottleNeck_bottom_3conv_1x1_1
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 4, 4, 64)     8256        batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_3x3 (None, 2, 2, 64)     36928       batch_normalization_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 4, 4, 64)     256         hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 2, 2, 64)     256         hg1_bottleNeck_bottom_3conv_3x3[0
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_3x (None, 4, 4, 64)     36928       batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3conv_1x1 (None, 2, 2, 128)    8320        batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# batch_normalization_288 (BatchN (None, 4, 4, 64)     256         hg1_bottleNeck4_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_bottom_3residual (None, 2, 2, 128)    0           hg1_bottleNeck_bottom_2residual_o
#                                                                  hg1_bottleNeck_bottom_3conv_1x1_2
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutconv_1x (None, 4, 4, 128)    8320        batch_normalization_288[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 4, 4, 128)    0           hg1_bottleNeck_bottom_3residual_o
# __________________________________________________________________________________________________
# hg1_bottleNeck4_shortcutresidua (None, 4, 4, 128)    0           hg1_bottleNeck4residual_output[0]
#                                                                  hg1_bottleNeck4_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 4, 4, 128)    0           up_sampling2d_20[0][0]
#                                                                  hg1_bottleNeck4_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 4, 4, 128)    512         add_25[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 4, 4, 64)     8256        batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 8, 8, 128)    512         hg1__bottleNeck3residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 4, 4, 64)     256         hg1_bottleNeck_right_4conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 8, 8, 64)     8256        batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_3x3  (None, 4, 4, 64)     36928       batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 8, 8, 64)     256         hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 4, 4, 64)     256         hg1_bottleNeck_right_4conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_3x (None, 8, 8, 64)     36928       batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4conv_1x1_ (None, 4, 4, 128)    8320        batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 8, 8, 64)     256         hg1_bottleNeck3_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_4residual_ (None, 4, 4, 128)    0           add_25[0][0]
#                                                                  hg1_bottleNeck_right_4conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutconv_1x (None, 8, 8, 128)    8320        batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 8, 8, 128)    0           hg1_bottleNeck_right_4residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck3_shortcutresidua (None, 8, 8, 128)    0           hg1__bottleNeck3residual_output[0
#                                                                  hg1_bottleNeck3_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 128)    0           up_sampling2d_21[0][0]
#                                                                  hg1_bottleNeck3_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 8, 8, 128)    512         add_26[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 8, 8, 64)     8256        batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 16, 16, 128)  512         hg1__bottleNeck2residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, 8, 8, 64)     256         hg1_bottleNeck_right_3conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 16, 16, 64)   8256        batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_3x3  (None, 8, 8, 64)     36928       batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 16, 16, 64)   256         hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, 8, 8, 64)     256         hg1_bottleNeck_right_3conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_3x (None, 16, 16, 64)   36928       batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3conv_1x1_ (None, 8, 8, 128)    8320        batch_normalization_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 16, 16, 64)   256         hg1_bottleNeck2_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_3residual_ (None, 8, 8, 128)    0           add_26[0][0]
#                                                                  hg1_bottleNeck_right_3conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutconv_1x (None, 16, 16, 128)  8320        batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 16, 16, 128)  0           hg1_bottleNeck_right_3residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck2_shortcutresidua (None, 16, 16, 128)  0           hg1__bottleNeck2residual_output[0
#                                                                  hg1_bottleNeck2_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 16, 16, 128)  0           up_sampling2d_22[0][0]
#                                                                  hg1_bottleNeck2_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, 16, 16, 128)  512         add_27[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 16, 16, 64)   8256        batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 32, 32, 128)  512         hg1__bottleNeck1residual_output[0
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, 16, 16, 64)   256         hg1_bottleNeck_right_2conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 32, 32, 64)   8256        batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_3x3  (None, 16, 16, 64)   36928       batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 32, 32, 64)   256         hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# batch_normalization_306 (BatchN (None, 16, 16, 64)   256         hg1_bottleNeck_right_2conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_3x (None, 32, 32, 64)   36928       batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2conv_1x1_ (None, 16, 16, 128)  8320        batch_normalization_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 32, 32, 64)   256         hg1_bottleNeck1_shortcutconv_3x3[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_2residual_ (None, 16, 16, 128)  0           add_27[0][0]
#                                                                  hg1_bottleNeck_right_2conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutconv_1x (None, 32, 32, 128)  8320        batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 32, 32, 128)  0           hg1_bottleNeck_right_2residual_ou
# __________________________________________________________________________________________________
# hg1_bottleNeck1_shortcutresidua (None, 32, 32, 128)  0           hg1__bottleNeck1residual_output[0
#                                                                  hg1_bottleNeck1_shortcutconv_1x1_
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 32, 32, 128)  0           up_sampling2d_23[0][0]
#                                                                  hg1_bottleNeck1_shortcutresidual_
# __________________________________________________________________________________________________
# batch_normalization_307 (BatchN (None, 32, 32, 128)  512         add_28[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 32, 32, 64)   8256        batch_normalization_307[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 32, 32, 64)   256         hg1_bottleNeck_right_1conv_1x1_1[
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_3x3  (None, 32, 32, 64)   36928       batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 32, 32, 64)   256         hg1_bottleNeck_right_1conv_3x3[0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1conv_1x1_ (None, 32, 32, 128)  8320        batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# hg1_bottleNeck_right_1residual_ (None, 32, 32, 128)  0           add_28[0][0]
#                                                                  hg1_bottleNeck_right_1conv_1x1_2[
# __________________________________________________________________________________________________
# hg1_Intermediate_conv_1x1_1 (Co (None, 32, 32, 128)  16512       hg1_bottleNeck_right_1residual_ou
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 32, 32, 128)  512         hg1_Intermediate_conv_1x1_1[0][0]
# __________________________________________________________________________________________________
# hg1_Intermediate_heatMap_conv_1 (None, 32, 32, 3)    387         batch_normalization_310[0][0]
# ==================================================================================================
# Total params: 1,783,826
# Trainable params: 1,766,924
# Non-trainable params: 16,902
# __________________________________________________________________________________________________

# %%
X_tra.shape
# Out:
# (258, 128, 128, 3)

# %%
model.compile(loss='mse',optimizer="rmsprop",sample_weight_mode="temporal")
model.fit(X_tra,y_tra,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-1ed9385329ee> in <module>
#       1 model.compile(loss='mse',optimizer="rmsprop",sample_weight_mode="temporal")
# ----> 2 model.fit(X_tra,y_tra,batch_size=batch_size,epochs=epochs,verbose=1)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:756 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\engine\compile_utils.py:203 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\losses.py:152 __call__
#         losses = call_fn(y_true, y_pred)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\losses.py:256 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\keras\losses.py:1198 mean_squared_error
#         return K.mean(math_ops.squared_difference(y_pred, y_true), axis=-1)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:10250 squared_difference
#         "SquaredDifference", x=x, y=y, name=name)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:750 _apply_op_helper
#         attrs=attr_protos, op_def=op_def)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:592 _create_op_internal
#         compute_device)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:3536 _create_op_internal
#         op_def=op_def)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:2016 __init__
#         control_input_ops, op_def)
#     C:\Users\warch\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1856 _create_c_op
#         raise ValueError(str(e))
#
#     ValueError: Dimensions must be equal, but are 32 and 128 for '{{node mean_squared_error/SquaredDifference}} = SquaredDifference[T=DT_FLOAT](model_2/hg0_Intermediate_heatMap_conv_1x1_1/BiasAdd, IteratorGetNext:1)' with input shapes: [?,32,32,3], [?,128,128,9].

# %%
"""
# construct the argument parse and parse the arguments
ap = argparse.ArgumentParser()

ap.add_argument("-nc", "--numClasses", type=int, default=16,
	help="number of classes")
ap.add_argument("-ns", "--numStacks", type=int, default=2,
	help="number of hourGlass stacks")
ap.add_argument("-nch", "--numChannels", type=int, default=256,
	help="number of residual bottleNeck channels")
ap.add_argument("-bs", "--batchSize", default=8, type=int,
    help='batch size for training')
ap.add_argument("-ep", "--epochs", default=20, type=int,
    help="number of traning epochs")
ap.add_argument("-rs", "--resume", default=False, type=bool,
    help="resume training or not")
ap.add_argument("-rsm", "--resumeModel",
    help="start point to retrain")
ap.add_argument("-rsmj", "--resumeModelJson",
    help="model json")
ap.add_argument("-c", "--checkPoints", required=True,
	help="path to output checkPoint directory")
ap.add_argument("-s", "--startEpoch", type=int, default=0,
	help="epoch to restart training at")

args = vars(ap.parse_args())
"""
#dataset_path = "data/mpii/"
batch_size = 8
epochs = 50

#Start training
print("[INFO]Loading training dataset...")
#train = MPIIDataGen(dataset_path + "mpii_annotations.json", dataset_path + "images", inres=(256,256), outres=(64,64), is_train=True)
#train_generator = train.generator(batch_size, args["numStacks"], sigma=1, is_shuffle=True, rot_flag=True, scale_flag=True, flip_flag=True)

#csvlogger = CSVLogger(os.path.join(args["checkPoints"], "csv_train_" + str(datetime.datetime.now().strftime('%H:%M')) + ".csv"))
#checkPoint = EvalCallBack(args["checkPoints"], (256,256), (64,64))

#callBacks = [csvlogger, checkPoint]

model = stack_hourGlass_modules(16, 2, 384, (384,384))
    
#show model summary
model.summary()
model.compile(optimizer=RMSprop(lr=5e-4), loss=mean_squared_error, metrics=["accuracy"])
print("[INFO]Training...")
model.fit_generator(generator=train_generator, steps_per_epoch=train.get_dataset_size() // batch_size,
                                 epochs=epochs, callbacks=callBacks)
print("[INFO]Finished training...")




#Resume Training
print("[INFO]Loading the model...")
with open(args["resumeModelJson"]) as f:
    model = model_from_json(f.read())
model.load_weights(args["resumeModel"])

model.compile(optimizer=RMSprop(lr=5e-4), loss=mean_squared_error, metrics=["accuracy"])
print("[INFO]Loading training dataset...")
train = MPIIDataGen(dataset_path + "mpii_annotations.json", dataset_path + "images", inres=(256,256), outres=(64,64), is_train=True)
train_generator = train.generator(batch_size, args["numStacks"], sigma=1, is_shuffle=True, rot_flag=True, scale_flag=True, flip_flag=True)

csvlogger = CSVLogger(os.path.join(args["checkPoints"], "csv_train_" + str(datetime.datetime.now().strftime('%H:%M')) + ".csv"))

checkpoint = EvalCallBack(args["checkPoints"], (256,256), (64,64))

callBacks = [csvlogger, checkpoint]
print("[INFO]Training...")
model.fit_generator(generator=train_generator, steps_per_epoch=train.get_dataset_size() // batch_size,
                                 initial_epoch=args["startEpoch"], epochs=epochs, callbacks=callBacks)
print("[INFO]Finished training...")

# %%
prop_train = 0.9
Ntrain = int(X_train.shape[0]*prop_train)
X_tra, y_tra, X_val,y_val = X_train[:Ntrain],y_train[:Ntrain],X_train[Ntrain:],y_train[Ntrain:]
del X_train, y_train

# %%
input_height, input_width = 96, 96
## output shape is the same as input
output_height, output_width = input_height, input_width 

# nClasses = 15
nClasses = 9 # ironman

# %%
model = []

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
# load weights into new model

loaded_model.load_weights("my_model_weights.hdf5")
model = loaded_model
model.compile(loss='mse',optimizer="rmsprop",sample_weight_mode="temporal")

print(model.output.shape)
# Out:
# (None, 82944, 1)

# %%
y_pred = model.predict(X_val)
y_pred = y_pred.reshape(-1,output_height,output_width,nClasses)

Nlandmark = y_pred.shape[-1]

# %%
for i in range(10):
	fig = plt.figure(figsize=(3,3))
	ax = fig.add_subplot(1,1,1)
	ax.imshow(X_val[i,:,:,0],cmap="gray")
	ax.axis("off")
	
	fig = plt.figure(figsize=(20,3))
	count = 1
	for j in range(9):
		ax = fig.add_subplot(2,Nlandmark,count)
# 		ax.set_title(lab[:10] + "\n" + lab[10:-2])
		ax.axis("off")
		count += 1
		ax.imshow(y_pred[i,:,:,j])
		if j == 0:
			ax.set_ylabel("prediction")
			
	for j in range(9):
		ax = fig.add_subplot(2,Nlandmark,count)
		count += 1
		ax.imshow(y_val[i,:,:,j])   
		ax.axis("off")
		if j == 0:
			ax.set_ylabel("true")

	img_name = './out/img_{:03d}.png'.format(i)
	plt.savefig( img_name, bbox_inches='tight', dpi=(300) )
	#plt.show()
	plt.close()
